# %% [markdown]
# - Run the standardisation only for valid models with ∆ AIC ≤ 6

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# Load libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import logging
logging.basicConfig(level=logging.CRITICAL) # ignore no handles to put in legend warning from matplotlib
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) # ignore Future deprecation warning
import os
import pickle

from classes import boundaries as bd
from classes import snag_MTF_func as sg

# %matplotlib inline
# %config Completer.use_jedi = False 




#--- Notebook run settings
run = 'command line' # 'manual' 'command line'
#run = 'manual'


# Settings for the multiple linear regression model (MLR)
#--- Arguments
if run == 'command line':
    # Read command line arguments
    arguments = os.environ['NB_ARGS']
    climate_data, alpha, date_exp_str, remove_data = arguments.split(',')
    
    alpha              = float(alpha)   
    remove_data        = bool(remove_data)
    
elif run == 'manual':
    # Enter arguments manually 
    alpha              = 0.01
    date_exp_str       = '230207_Full'
    climate_data_list  = ['CRUclim','CRUNCEPv7','CHELSA30s','WorldClim30s','WorldClim10m',]
    climate_data       = climate_data_list[1]
    remove_data        = True
    
print(date_exp_str, alpha, remove_data)
# Out:
# 230116_Full_Management 0.01 True

# %%
#---------------#
#  Import data  #
#---------------#
mtf_type = ['count','cmass']

#--- Experiments
with open('site_reg_results/'+date_exp_str+'_SITE_reg_experiments_list.pkl', 'rb') as f:
    experiments = pickle.load(f)    

# Isolate unique variables in experiment list for standardisation of covars
strings     = [i.replace('MTF ~ ','') for i in experiments]
strings     = [i.split(' * ')[0] for i in strings]
strings     = [i.split(' + ') for i in strings]
flat_list   = [item for sublist in strings for item in sublist]
var_list_in = np.unique(flat_list)    

# Data        
cols = ['Reference','Continent','Country','Site name','MTF','MTF basis', 'DBH mean','MAP','Insects','MATsoil',
        'CDI','Managed','Fire','Mortality','MAT','Humidity','PFT','Soil_water','Soil_water_max']    
    
site_mtf = sg.MTF_database_import('data/MTF_database.xlsx','Site_MTF',engine=True)
site_mtf.loc[site_mtf['Site name'].isna(),['Site name']] = ''
site_mtf.loc[site_mtf['Y coords'].isna(),['Y coords']] = ''
site_mtf.loc[site_mtf['X coords'].isna(),['X coords']] = ''
site_mtf_cp = site_mtf.copy()
site_mtf['MAT'] = site_mtf[(climate_data,'MAT')]
site_mtf['MAP'] = site_mtf[(climate_data,'MAP')]
mtf = site_mtf.loc[:, cols].copy()

mtf.columns = mtf.columns.get_level_values(0)
mtf_cp = mtf.copy()

    
#--- Remove data
if remove_data:
    mtf = mtf[~(mtf.Reference == 'Ritchie2014EstablishmentForest')].copy()
    mtf = mtf[(mtf.Reference != 'Campbell2016CarbonStates')].copy()
    
    if 'FireOnly' in date_exp_str:
        mtf = mtf[(mtf.Fire == 1)]
    
    if 'NoFire' in date_exp_str:
        mtf = mtf[(mtf.Fire == 0)]
    
    if 'NoInsectsFire' in date_exp_str:
        mtf = mtf[(mtf.Fire == 0) & (mtf.Insects == 0)]

    
#--------------------#
#   Transform data   #
#--------------------#

mtf.loc[:, 'MTF'] = mtf.loc[:, 'MTF'].apply(np.log)
site_mtf_cp.loc[:, ['MTF']] = site_mtf_cp.loc[:, ['MTF']].apply(np.log)

# Drop subset based on data subset
if 'Moisture' in date_exp_str:
    mtf = mtf.dropna(subset=['DBH mean','MAT','Humidity','PFT','Soil_water', 'Soil_water_max'])  
elif 'Management' in date_exp_str:
    mtf = mtf.dropna(subset=['DBH mean','MAT','Humidity','PFT','Managed']) 
    print('hi')
else:
    mtf = mtf.dropna(subset=['DBH mean','MAT','Humidity','PFT']) 
    

# Rename columns to work with OLS
cols       = mtf.columns.values
index_dbh  = mtf.columns.get_loc('DBH mean')
cols[index_dbh]  = 'DBH_mean'
mtf.columns = cols


#--- Seperate date according to MTF type
mtf_count = mtf[(mtf['MTF basis'] == 'count') & (mtf.MTF.notnull())].copy().reset_index(drop=True)
mtf_cmass = mtf[(mtf['MTF basis'] == 'cmass') & (mtf.MTF.notnull())].copy()
mtf_c     = mtf[(mtf['MTF basis'] == 'c') & (mtf.MTF.notnull())].copy()   

# Combine data into list for loop
data = [mtf_count, mtf_cmass]
# Out:
# hi

# %%
standardise_covars_list = [False, True]

# Initialise storage
reg_results = np.empty((len(standardise_covars_list),len(mtf_type),2), dtype='object')

for st in range(len(standardise_covars_list)):
    standardise_covars = standardise_covars_list[st]
    
    if standardise_covars:
        bd.print_header('Standardising covariates')
    for t,tp in enumerate(mtf_type):
        bd.print_TITLE(tp)

        mtf_reg = data[t].copy()


        if standardise_covars:
            
            for var in var_list_in:
                print(var, mtf_reg.loc[:,var].mean())
                if mtf_reg.loc[:,var].std() == 0:
                    print('\n'+tp+'t!\nSetting {} to 0 because Std is 0, i.e. standardisation fails!\n'.format(
                        var))
                    mtf_reg.loc[:,var] = 0
                else:
                    mtf_reg.loc[:,var] = ((mtf_reg.loc[:,var] - mtf_reg.loc[:,var].mean()) /
                                                mtf_reg.loc[:,var].std())  

        # Run regressions
        res_table, result_objs = sg.regression_wrapper(mtf_reg, experiments[:],alpha, tp, 
                                                       climate_data, standardise_covars)
        
        reg_results[st,t,0] = res_table
        reg_results[st,t,1] = result_objs

        display(res_table)

storage_string = 'site_reg_results/'+date_exp_str+'_SITE_'+str(alpha)+'_'+climate_data+'.pkl'
with open(storage_string, 'wb') as f:
    pickle.dump(reg_results, f)
# Out:
# ==============================
#
#              count
#
# ==============================
#                                                       r2    AIC  d_AIC   RMSE  \
# MTF ~ MAT + PFT + DBH_mean + Managed                0.37  147.5    0.5  23.34
# MTF ~ MAT + DBH_mean + Managed                      0.36  147.0    0.0  23.47
# MTF ~ MAT + Humidity + PFT + DBH_mean + Managed     0.36  149.1    2.1  23.34
# MTF ~ MAT + Humidity + DBH_mean + Managed           0.35  148.6    1.6  23.47
# MTF ~ MATsoil + PFT + DBH_mean + Managed            0.35  148.9    1.9  24.33
# MTF ~ MATsoil + DBH_mean + Managed                  0.34  148.7    1.7  24.48
# MTF ~ MATsoil + Humidity + DBH_mean + Managed       0.34  150.4    3.4  24.44
# MTF ~ MATsoil + Humidity + PFT + DBH_mean + Man...  0.34  150.7    3.7  24.29
# MTF ~ CDI + DBH_mean + Managed                      0.29  154.1    7.1  25.12
# MTF ~ MATsoil + PFT + DBH_mean                      0.29  154.1    7.1  25.23
# MTF ~ CDI + PFT + DBH_mean + Managed                0.29  155.0    8.0  25.00
# MTF ~ MATsoil + DBH_mean                            0.28  153.9    6.9  25.39
# MTF ~ MAT + Humidity + PFT + DBH_mean               0.28  156.0    9.0  24.41
# MTF ~ MATsoil + Humidity + PFT + DBH_mean           0.28  156.0    9.0  25.21
# MTF ~ MAT + PFT + DBH_mean                          0.27  155.5    8.5  24.47
# MTF ~ MAT + Humidity + DBH_mean                     0.27  155.6    8.6  24.56
# MTF ~ MATsoil + Humidity + DBH_mean                 0.27  155.9    8.9  25.37
# MTF ~ MAT + DBH_mean                                0.26  155.2    8.2  24.62
# MTF ~ CDI + Managed                                 0.25  156.6    9.6  26.42
# MTF ~ CDI + PFT + Managed                           0.25  157.1   10.1  26.21
# MTF ~ MAT + PFT + Managed                           0.25  157.5   10.5  25.80
# MTF ~ MATsoil + PFT + Managed                       0.25  157.6   10.6  26.29
# MTF ~ MAT + Humidity + PFT + Managed                0.24  158.9   11.9  25.87
# MTF ~ MAT + Managed                                 0.23  158.1   11.1  26.10
# MTF ~ MATsoil + Managed                             0.23  158.3   11.3  26.60
# MTF ~ PFT + DBH_mean + Managed                      0.23  159.3   12.3  25.14
# MTF ~ MATsoil + Humidity + PFT + Managed            0.23  159.6   12.6  26.30
# MTF ~ MAT + Humidity + Managed                      0.22  159.4   12.4  26.15
# MTF ~ Humidity + PFT + DBH_mean + Managed           0.22  161.1   14.1  25.15
# MTF ~ DBH_mean + Managed                            0.21  159.7   12.7  25.38
# MTF ~ MATsoil + Humidity + Managed                  0.21  160.3   13.3  26.61
# MTF ~ PFT + Managed                                 0.20  160.8   13.8  26.37
# MTF ~ Humidity + DBH_mean + Managed                 0.20  161.6   14.6  25.38
# MTF ~ Humidity + PFT + Managed                      0.19  162.5   15.5  26.41
# MTF ~ Managed                                       0.17  161.7   14.7  26.75
# MTF ~ CDI + DBH_mean                                0.17  162.5   15.5  26.63
# MTF ~ MATsoil + PFT                                 0.17  162.9   15.9  27.09
# MTF ~ CDI + PFT + DBH_mean                          0.17  163.4   16.4  26.50
# MTF ~ Humidity + Managed                            0.16  163.4   16.4  26.78
# MTF ~ MATsoil + Humidity + PFT                      0.16  164.7   17.7  27.13
# MTF ~ MAT + Humidity + PFT                          0.16  164.8   17.8  26.78
# MTF ~ CDI                                           0.15  163.5   16.5  27.50
# MTF ~ MATsoil                                       0.15  163.7   16.7  27.41
# MTF ~ CDI + PFT                                     0.15  164.1   17.1  27.30
# MTF ~ MAT + PFT                                     0.15  164.7   17.7  26.72
# MTF ~ MAT + Humidity                                0.13  165.5   18.5  27.09
# MTF ~ MATsoil + Humidity                            0.13  165.5   18.5  27.45
# MTF ~ MAT                                           0.12  165.4   18.4  27.03
# MTF ~ PFT + DBH_mean                                0.05  171.7   24.7  27.06
# MTF ~ Humidity + PFT + DBH_mean                     0.05  172.3   25.3  26.90
# MTF ~ Humidity + PFT                                0.04  172.1   25.1  27.72
# MTF ~ PFT                                           0.03  171.6   24.6  27.80
# MTF ~ DBH_mean                                      0.02  172.5   25.5  27.38
# MTF ~ Humidity + DBH_mean                           0.02  173.2   26.2  27.20
# MTF ~ Humidity                                      0.01  173.3   26.3  28.13
#
#                                                      DWT prms_sig  \
# MTF ~ MAT + PFT + DBH_mean + Managed                1.60    False
# MTF ~ MAT + DBH_mean + Managed                      1.62     True
# MTF ~ MAT + Humidity + PFT + DBH_mean + Managed     1.60    False
# MTF ~ MAT + Humidity + DBH_mean + Managed           1.62    False
# MTF ~ MATsoil + PFT + DBH_mean + Managed            1.53    False
# MTF ~ MATsoil + DBH_mean + Managed                  1.54     True
# MTF ~ MATsoil + Humidity + DBH_mean + Managed       1.53    False
# MTF ~ MATsoil + Humidity + PFT + DBH_mean + Man...  1.52    False
# MTF ~ CDI + DBH_mean + Managed                      1.62    False
# MTF ~ MATsoil + PFT + DBH_mean                      1.38    False
# MTF ~ CDI + PFT + DBH_mean + Managed                1.61    False
# MTF ~ MATsoil + DBH_mean                            1.36     True
# MTF ~ MAT + Humidity + PFT + DBH_mean               1.43    False
# MTF ~ MATsoil + Humidity + PFT + DBH_mean           1.38    False
# MTF ~ MAT + PFT + DBH_mean                          1.45    False
# MTF ~ MAT + Humidity + DBH_mean                     1.42    False
# MTF ~ MATsoil + Humidity + DBH_mean                 1.36    False
# MTF ~ MAT + DBH_mean                                1.43     True
# MTF ~ CDI + Managed                                 1.68     True
# MTF ~ CDI + PFT + Managed                           1.64    False
# MTF ~ MAT + PFT + Managed                           1.60    False
# MTF ~ MATsoil + PFT + Managed                       1.55    False
# MTF ~ MAT + Humidity + PFT + Managed                1.58    False
# MTF ~ MAT + Managed                                 1.67    False
# MTF ~ MATsoil + Managed                             1.62    False
# MTF ~ PFT + DBH_mean + Managed                      1.68    False
# MTF ~ MATsoil + Humidity + PFT + Managed            1.55    False
# MTF ~ MAT + Humidity + Managed                      1.66    False
# MTF ~ Humidity + PFT + DBH_mean + Managed           1.67    False
# MTF ~ DBH_mean + Managed                            1.69    False
# MTF ~ MATsoil + Humidity + Managed                  1.62    False
# MTF ~ PFT + Managed                                 1.71    False
# MTF ~ Humidity + DBH_mean + Managed                 1.68    False
# MTF ~ Humidity + PFT + Managed                      1.70    False
# MTF ~ Managed                                       1.76     True
# MTF ~ CDI + DBH_mean                                1.42    False
# MTF ~ MATsoil + PFT                                 1.35    False
# MTF ~ CDI + PFT + DBH_mean                          1.43    False
# MTF ~ Humidity + Managed                            1.75    False
# MTF ~ MATsoil + Humidity + PFT                      1.36    False
# MTF ~ MAT + Humidity + PFT                          1.39    False
# MTF ~ CDI                                           1.48     True
# MTF ~ MATsoil                                       1.38     True
# MTF ~ CDI + PFT                                     1.47    False
# MTF ~ MAT + PFT                                     1.41    False
# MTF ~ MAT + Humidity                                1.42    False
# MTF ~ MATsoil + Humidity                            1.38    False
# MTF ~ MAT                                           1.43     True
# MTF ~ PFT + DBH_mean                                1.43    False
# MTF ~ Humidity + PFT + DBH_mean                     1.40    False
# MTF ~ Humidity + PFT                                1.43    False
# MTF ~ PFT                                           1.47    False
# MTF ~ DBH_mean                                      1.38    False
# MTF ~ Humidity + DBH_mean                           1.35    False
# MTF ~ Humidity                                      1.42    False
#
#                                                                           prms_fail  \
# MTF ~ MAT + PFT + DBH_mean + Managed                                            PFT
# MTF ~ MAT + DBH_mean + Managed
# MTF ~ MAT + Humidity + PFT + DBH_mean + Managed                       Humidity, PFT
# MTF ~ MAT + Humidity + DBH_mean + Managed                                  Humidity
# MTF ~ MATsoil + PFT + DBH_mean + Managed                               PFT, Managed
# MTF ~ MATsoil + DBH_mean + Managed
# MTF ~ MATsoil + Humidity + DBH_mean + Managed                              Humidity
# MTF ~ MATsoil + Humidity + PFT + DBH_mean + Man...           Humidity, PFT, Managed
# MTF ~ CDI + DBH_mean + Managed                                             DBH_mean
# MTF ~ MATsoil + PFT + DBH_mean                                                  PFT
# MTF ~ CDI + PFT + DBH_mean + Managed                             CDI, PFT, DBH_mean
# MTF ~ MATsoil + DBH_mean
# MTF ~ MAT + Humidity + PFT + DBH_mean                                 Humidity, PFT
# MTF ~ MATsoil + Humidity + PFT + DBH_mean                             Humidity, PFT
# MTF ~ MAT + PFT + DBH_mean                                                      PFT
# MTF ~ MAT + Humidity + DBH_mean                                            Humidity
# MTF ~ MATsoil + Humidity + DBH_mean                                        Humidity
# MTF ~ MAT + DBH_mean
# MTF ~ CDI + Managed
# MTF ~ CDI + PFT + Managed                                                  CDI, PFT
# MTF ~ MAT + PFT + Managed                                                  MAT, PFT
# MTF ~ MATsoil + PFT + Managed                                          MATsoil, PFT
# MTF ~ MAT + Humidity + PFT + Managed                             MAT, Humidity, PFT
# MTF ~ MAT + Managed                                                             MAT
# MTF ~ MATsoil + Managed                                                     MATsoil
# MTF ~ PFT + DBH_mean + Managed                                        PFT, DBH_mean
# MTF ~ MATsoil + Humidity + PFT + Managed            MATsoil, Humidity, PFT, Managed
# MTF ~ MAT + Humidity + Managed                                        MAT, Humidity
# MTF ~ Humidity + PFT + DBH_mean + Managed                   Humidity, PFT, DBH_mean
# MTF ~ DBH_mean + Managed                                                   DBH_mean
# MTF ~ MATsoil + Humidity + Managed                                MATsoil, Humidity
# MTF ~ PFT + Managed                                                             PFT
# MTF ~ Humidity + DBH_mean + Managed                              Humidity, DBH_mean
# MTF ~ Humidity + PFT + Managed                                        Humidity, PFT
# MTF ~ Managed
# MTF ~ CDI + DBH_mean                                                       DBH_mean
# MTF ~ MATsoil + PFT                                                             PFT
# MTF ~ CDI + PFT + DBH_mean                                            PFT, DBH_mean
# MTF ~ Humidity + Managed                                                   Humidity
# MTF ~ MATsoil + Humidity + PFT                                        Humidity, PFT
# MTF ~ MAT + Humidity + PFT                                            Humidity, PFT
# MTF ~ CDI
# MTF ~ MATsoil
# MTF ~ CDI + PFT                                                                 PFT
# MTF ~ MAT + PFT                                                                 PFT
# MTF ~ MAT + Humidity                                                       Humidity
# MTF ~ MATsoil + Humidity                                                   Humidity
# MTF ~ MAT
# MTF ~ PFT + DBH_mean                                                  PFT, DBH_mean
# MTF ~ Humidity + PFT + DBH_mean                             Humidity, PFT, DBH_mean
# MTF ~ Humidity + PFT                                                  Humidity, PFT
# MTF ~ PFT                                                                       PFT
# MTF ~ DBH_mean                                                             DBH_mean
# MTF ~ Humidity + DBH_mean                                        Humidity, DBH_mean
# MTF ~ Humidity                                                             Humidity
#
#                                                     N_obs  ID MTF_basis  \
# MTF ~ MAT + PFT + DBH_mean + Managed                 64.0   0     count
# MTF ~ MAT + DBH_mean + Managed                       64.0   1     count
# MTF ~ MAT + Humidity + PFT + DBH_mean + Managed      64.0   2     count
# MTF ~ MAT + Humidity + DBH_mean + Managed            64.0   3     count
# MTF ~ MATsoil + PFT + DBH_mean + Managed             64.0   4     count
# MTF ~ MATsoil + DBH_mean + Managed                   64.0   5     count
# MTF ~ MATsoil + Humidity + DBH_mean + Managed        64.0   6     count
# MTF ~ MATsoil + Humidity + PFT + DBH_mean + Man...   64.0   7     count
# MTF ~ CDI + DBH_mean + Managed                       64.0   8     count
# MTF ~ MATsoil + PFT + DBH_mean                       64.0   9     count
# MTF ~ CDI + PFT + DBH_mean + Managed                 64.0  10     count
# MTF ~ MATsoil + DBH_mean                             64.0  11     count
# MTF ~ MAT + Humidity + PFT + DBH_mean                64.0  12     count
# MTF ~ MATsoil + Humidity + PFT + DBH_mean            64.0  13     count
# MTF ~ MAT + PFT + DBH_mean                           64.0  14     count
# MTF ~ MAT + Humidity + DBH_mean                      64.0  15     count
# MTF ~ MATsoil + Humidity + DBH_mean                  64.0  16     count
# MTF ~ MAT + DBH_mean                                 64.0  17     count
# MTF ~ CDI + Managed                                  64.0  18     count
# MTF ~ CDI + PFT + Managed                            64.0  19     count
# MTF ~ MAT + PFT + Managed                            64.0  20     count
# MTF ~ MATsoil + PFT + Managed                        64.0  21     count
# MTF ~ MAT + Humidity + PFT + Managed                 64.0  22     count
# MTF ~ MAT + Managed                                  64.0  23     count
# MTF ~ MATsoil + Managed                              64.0  24     count
# MTF ~ PFT + DBH_mean + Managed                       64.0  25     count
# MTF ~ MATsoil + Humidity + PFT + Managed             64.0  26     count
# MTF ~ MAT + Humidity + Managed                       64.0  27     count
# MTF ~ Humidity + PFT + DBH_mean + Managed            64.0  28     count
# MTF ~ DBH_mean + Managed                             64.0  29     count
# MTF ~ MATsoil + Humidity + Managed                   64.0  30     count
# MTF ~ PFT + Managed                                  64.0  31     count
# MTF ~ Humidity + DBH_mean + Managed                  64.0  32     count
# MTF ~ Humidity + PFT + Managed                       64.0  33     count
# MTF ~ Managed                                        64.0  34     count
# MTF ~ CDI + DBH_mean                                 64.0  35     count
# MTF ~ MATsoil + PFT                                  64.0  36     count
# MTF ~ CDI + PFT + DBH_mean                           64.0  37     count
# MTF ~ Humidity + Managed                             64.0  38     count
# MTF ~ MATsoil + Humidity + PFT                       64.0  39     count
# MTF ~ MAT + Humidity + PFT                           64.0  40     count
# MTF ~ CDI                                            64.0  41     count
# MTF ~ MATsoil                                        64.0  42     count
# MTF ~ CDI + PFT                                      64.0  43     count
# MTF ~ MAT + PFT                                      64.0  44     count
# MTF ~ MAT + Humidity                                 64.0  45     count
# MTF ~ MATsoil + Humidity                             64.0  46     count
# MTF ~ MAT                                            64.0  47     count
# MTF ~ PFT + DBH_mean                                 64.0  48     count
# MTF ~ Humidity + PFT + DBH_mean                      64.0  49     count
# MTF ~ Humidity + PFT                                 64.0  50     count
# MTF ~ PFT                                            64.0  51     count
# MTF ~ DBH_mean                                       64.0  52     count
# MTF ~ Humidity + DBH_mean                            64.0  53     count
# MTF ~ Humidity                                       64.0  54     count
#
#                                                       climate  \
# MTF ~ MAT + PFT + DBH_mean + Managed                CRUNCEPv7
# MTF ~ MAT + DBH_mean + Managed                      CRUNCEPv7
# MTF ~ MAT + Humidity + PFT + DBH_mean + Managed     CRUNCEPv7
# MTF ~ MAT + Humidity + DBH_mean + Managed           CRUNCEPv7
# MTF ~ MATsoil + PFT + DBH_mean + Managed            CRUNCEPv7
# MTF ~ MATsoil + DBH_mean + Managed                  CRUNCEPv7
# MTF ~ MATsoil + Humidity + DBH_mean + Managed       CRUNCEPv7
# MTF ~ MATsoil + Humidity + PFT + DBH_mean + Man...  CRUNCEPv7
# MTF ~ CDI + DBH_mean + Managed                      CRUNCEPv7
# MTF ~ MATsoil + PFT + DBH_mean                      CRUNCEPv7
# MTF ~ CDI + PFT + DBH_mean + Managed                CRUNCEPv7
# MTF ~ MATsoil + DBH_mean                            CRUNCEPv7
# MTF ~ MAT + Humidity + PFT + DBH_mean               CRUNCEPv7
# MTF ~ MATsoil + Humidity + PFT + DBH_mean           CRUNCEPv7
# MTF ~ MAT + PFT + DBH_mean                          CRUNCEPv7
# MTF ~ MAT + Humidity + DBH_mean                     CRUNCEPv7
# MTF ~ MATsoil + Humidity + DBH_mean                 CRUNCEPv7
# MTF ~ MAT + DBH_mean                                CRUNCEPv7
# MTF ~ CDI + Managed                                 CRUNCEPv7
# MTF ~ CDI + PFT + Managed                           CRUNCEPv7
# MTF ~ MAT + PFT + Managed                           CRUNCEPv7
# MTF ~ MATsoil + PFT + Managed                       CRUNCEPv7
# MTF ~ MAT + Humidity + PFT + Managed                CRUNCEPv7
# MTF ~ MAT + Managed                                 CRUNCEPv7
# MTF ~ MATsoil + Managed                             CRUNCEPv7
# MTF ~ PFT + DBH_mean + Managed                      CRUNCEPv7
# MTF ~ MATsoil + Humidity + PFT + Managed            CRUNCEPv7
# MTF ~ MAT + Humidity + Managed                      CRUNCEPv7
# MTF ~ Humidity + PFT + DBH_mean + Managed           CRUNCEPv7
# MTF ~ DBH_mean + Managed                            CRUNCEPv7
# MTF ~ MATsoil + Humidity + Managed                  CRUNCEPv7
# MTF ~ PFT + Managed                                 CRUNCEPv7
# MTF ~ Humidity + DBH_mean + Managed                 CRUNCEPv7
# MTF ~ Humidity + PFT + Managed                      CRUNCEPv7
# MTF ~ Managed                                       CRUNCEPv7
# MTF ~ CDI + DBH_mean                                CRUNCEPv7
# MTF ~ MATsoil + PFT                                 CRUNCEPv7
# MTF ~ CDI + PFT + DBH_mean                          CRUNCEPv7
# MTF ~ Humidity + Managed                            CRUNCEPv7
# MTF ~ MATsoil + Humidity + PFT                      CRUNCEPv7
# MTF ~ MAT + Humidity + PFT                          CRUNCEPv7
# MTF ~ CDI                                           CRUNCEPv7
# MTF ~ MATsoil                                       CRUNCEPv7
# MTF ~ CDI + PFT                                     CRUNCEPv7
# MTF ~ MAT + PFT                                     CRUNCEPv7
# MTF ~ MAT + Humidity                                CRUNCEPv7
# MTF ~ MATsoil + Humidity                            CRUNCEPv7
# MTF ~ MAT                                           CRUNCEPv7
# MTF ~ PFT + DBH_mean                                CRUNCEPv7
# MTF ~ Humidity + PFT + DBH_mean                     CRUNCEPv7
# MTF ~ Humidity + PFT                                CRUNCEPv7
# MTF ~ PFT                                           CRUNCEPv7
# MTF ~ DBH_mean                                      CRUNCEPv7
# MTF ~ Humidity + DBH_mean                           CRUNCEPv7
# MTF ~ Humidity                                      CRUNCEPv7
#
#                                                     standardised_covars
# MTF ~ MAT + PFT + DBH_mean + Managed                              False
# MTF ~ MAT + DBH_mean + Managed                                    False
# MTF ~ MAT + Humidity + PFT + DBH_mean + Managed                   False
# MTF ~ MAT + Humidity + DBH_mean + Managed                         False
# MTF ~ MATsoil + PFT + DBH_mean + Managed                          False
# MTF ~ MATsoil + DBH_mean + Managed                                False
# MTF ~ MATsoil + Humidity + DBH_mean + Managed                     False
# MTF ~ MATsoil + Humidity + PFT + DBH_mean + Man...                False
# MTF ~ CDI + DBH_mean + Managed                                    False
# MTF ~ MATsoil + PFT + DBH_mean                                    False
# MTF ~ CDI + PFT + DBH_mean + Managed                              False
# MTF ~ MATsoil + DBH_mean                                          False
# MTF ~ MAT + Humidity + PFT + DBH_mean                             False
# MTF ~ MATsoil + Humidity + PFT + DBH_mean                         False
# MTF ~ MAT + PFT + DBH_mean                                        False
# MTF ~ MAT + Humidity + DBH_mean                                   False
# MTF ~ MATsoil + Humidity + DBH_mean                               False
# MTF ~ MAT + DBH_mean                                              False
# MTF ~ CDI + Managed                                               False
# MTF ~ CDI + PFT + Managed                                         False
# MTF ~ MAT + PFT + Managed                                         False
# MTF ~ MATsoil + PFT + Managed                                     False
# MTF ~ MAT + Humidity + PFT + Managed                              False
# MTF ~ MAT + Managed                                               False
# MTF ~ MATsoil + Managed                                           False
# MTF ~ PFT + DBH_mean + Managed                                    False
# MTF ~ MATsoil + Humidity + PFT + Managed                          False
# MTF ~ MAT + Humidity + Managed                                    False
# MTF ~ Humidity + PFT + DBH_mean + Managed                         False
# MTF ~ DBH_mean + Managed                                          False
# MTF ~ MATsoil + Humidity + Managed                                False
# MTF ~ PFT + Managed                                               False
# MTF ~ Humidity + DBH_mean + Managed                               False
# MTF ~ Humidity + PFT + Managed                                    False
# MTF ~ Managed                                                     False
# MTF ~ CDI + DBH_mean                                              False
# MTF ~ MATsoil + PFT                                               False
# MTF ~ CDI + PFT + DBH_mean                                        False
# MTF ~ Humidity + Managed                                          False
# MTF ~ MATsoil + Humidity + PFT                                    False
# MTF ~ MAT + Humidity + PFT                                        False
# MTF ~ CDI                                                         False
# MTF ~ MATsoil                                                     False
# MTF ~ CDI + PFT                                                   False
# MTF ~ MAT + PFT                                                   False
# MTF ~ MAT + Humidity                                              False
# MTF ~ MATsoil + Humidity                                          False
# MTF ~ MAT                                                         False
# MTF ~ PFT + DBH_mean                                              False
# MTF ~ Humidity + PFT + DBH_mean                                   False
# MTF ~ Humidity + PFT                                              False
# MTF ~ PFT                                                         False
# MTF ~ DBH_mean                                                    False
# MTF ~ Humidity + DBH_mean                                         False
# MTF ~ Humidity                                                    False
# ==============================
#
#              cmass
#
# ==============================
#                                                       r2    AIC  d_AIC   RMSE  \
# MTF ~ MAT + DBH_mean + Managed                      0.42  150.8    0.0  49.30
# MTF ~ MAT + PFT + DBH_mean + Managed                0.42  151.3    0.5  48.99
# MTF ~ MAT + Humidity + DBH_mean + Managed           0.42  152.1    1.3  49.33
# MTF ~ MAT + Humidity + PFT + DBH_mean + Managed     0.42  152.6    1.8  49.03
# MTF ~ MATsoil + DBH_mean + Managed                  0.41  152.2    1.4  51.17
# MTF ~ MATsoil + PFT + DBH_mean + Managed            0.41  152.4    1.6  50.86
# MTF ~ MATsoil + Humidity + PFT + DBH_mean + Man...  0.41  154.1    3.3  50.79
# MTF ~ MATsoil + Humidity + DBH_mean + Managed       0.40  153.9    3.1  51.11
# MTF ~ MATsoil + PFT + DBH_mean                      0.34  158.7    7.9  52.53
# MTF ~ MATsoil + DBH_mean                            0.33  158.6    7.8  52.86
# MTF ~ MATsoil + Humidity + PFT + DBH_mean           0.33  160.6    9.8  52.51
# MTF ~ MAT + Humidity + PFT + DBH_mean               0.33  161.1   10.3  51.06
# MTF ~ MATsoil + Humidity + DBH_mean                 0.32  160.5    9.7  52.84
# MTF ~ MAT + Humidity + DBH_mean                     0.32  160.7    9.9  51.38
# MTF ~ CDI + DBH_mean + Managed                      0.32  161.0   10.2  52.12
# MTF ~ MAT + PFT + DBH_mean                          0.32  161.3   10.5  51.12
# MTF ~ CDI + PFT + DBH_mean + Managed                0.32  161.9   11.1  51.86
# MTF ~ MAT + DBH_mean                                0.31  160.9   10.1  51.45
# MTF ~ MATsoil + PFT + Managed                       0.30  162.5   11.7  53.74
# MTF ~ MAT + PFT + Managed                           0.30  162.8   12.0  52.59
# MTF ~ MAT + Humidity + PFT + Managed                0.30  163.8   13.0  52.79
# MTF ~ CDI + Managed                                 0.29  163.1   12.3  54.05
# MTF ~ CDI + PFT + Managed                           0.29  163.6   12.8  53.66
# MTF ~ MATsoil + Humidity + PFT + Managed            0.29  164.5   13.7  53.77
# MTF ~ MATsoil + Managed                             0.28  163.3   12.5  54.30
# MTF ~ MAT + Managed                                 0.28  163.4   12.6  53.14
# MTF ~ MAT + Humidity + Managed                      0.28  164.4   13.6  53.32
# MTF ~ MATsoil + Humidity + Managed                  0.27  165.3   14.5  54.33
# MTF ~ PFT + DBH_mean + Managed                      0.25  167.4   16.6  52.01
# MTF ~ Humidity + PFT + DBH_mean + Managed           0.24  169.1   18.3  52.05
# MTF ~ DBH_mean + Managed                            0.23  167.9   17.1  52.51
# MTF ~ PFT + Managed                                 0.22  168.5   17.7  53.91
# MTF ~ MATsoil + PFT                                 0.22  168.8   18.0  55.28
# MTF ~ Humidity + DBH_mean + Managed                 0.22  169.6   18.8  52.53
# MTF ~ Humidity + PFT + Managed                      0.22  170.0   19.2  54.03
# MTF ~ MATsoil + Humidity + PFT                      0.21  170.5   19.7  55.38
# MTF ~ Managed                                       0.20  169.5   18.7  54.66
# MTF ~ MATsoil                                       0.20  169.7   18.9  55.86
# MTF ~ MAT + Humidity + PFT                          0.20  171.0   20.2  54.67
# MTF ~ Humidity + Managed                            0.19  171.0   20.2  54.74
# MTF ~ CDI + DBH_mean                                0.19  171.1   20.3  55.19
# MTF ~ MATsoil + Humidity                            0.19  171.4   20.6  55.96
# MTF ~ MAT + PFT                                     0.19  171.5   20.7  54.45
# MTF ~ CDI + PFT + DBH_mean                          0.19  172.0   21.2  54.92
# MTF ~ MAT + Humidity                                0.18  171.7   20.9  55.25
# MTF ~ CDI                                           0.17  171.7   20.9  56.39
# MTF ~ CDI + PFT                                     0.17  172.4   21.6  56.01
# MTF ~ MAT                                           0.16  172.3   21.5  55.04
# MTF ~ Humidity + PFT                                0.05  181.5   30.7  56.77
# MTF ~ Humidity + PFT + DBH_mean                     0.05  182.1   31.3  55.54
# MTF ~ PFT + DBH_mean                                0.04  181.8   31.0  55.88
# MTF ~ PFT                                           0.03  181.4   30.6  56.93
# MTF ~ Humidity + DBH_mean                           0.02  183.0   32.2  56.13
# MTF ~ DBH_mean                                      0.01  182.7   31.9  56.51
# MTF ~ Humidity                                      0.01  182.7   31.9  57.56
#
#                                                      DWT prms_sig  \
# MTF ~ MAT + DBH_mean + Managed                      1.71     True
# MTF ~ MAT + PFT + DBH_mean + Managed                1.67    False
# MTF ~ MAT + Humidity + DBH_mean + Managed           1.71    False
# MTF ~ MAT + Humidity + PFT + DBH_mean + Managed     1.67    False
# MTF ~ MATsoil + DBH_mean + Managed                  1.59     True
# MTF ~ MATsoil + PFT + DBH_mean + Managed            1.56    False
# MTF ~ MATsoil + Humidity + PFT + DBH_mean + Man...  1.56    False
# MTF ~ MATsoil + Humidity + DBH_mean + Managed       1.59    False
# MTF ~ MATsoil + PFT + DBH_mean                      1.41    False
# MTF ~ MATsoil + DBH_mean                            1.40     True
# MTF ~ MATsoil + Humidity + PFT + DBH_mean           1.41    False
# MTF ~ MAT + Humidity + PFT + DBH_mean               1.48    False
# MTF ~ MATsoil + Humidity + DBH_mean                 1.40    False
# MTF ~ MAT + Humidity + DBH_mean                     1.49    False
# MTF ~ CDI + DBH_mean + Managed                      1.65    False
# MTF ~ MAT + PFT + DBH_mean                          1.49    False
# MTF ~ CDI + PFT + DBH_mean + Managed                1.62    False
# MTF ~ MAT + DBH_mean                                1.49     True
# MTF ~ MATsoil + PFT + Managed                       1.51    False
# MTF ~ MAT + PFT + Managed                           1.58    False
# MTF ~ MAT + Humidity + PFT + Managed                1.57    False
# MTF ~ CDI + Managed                                 1.70     True
# MTF ~ CDI + PFT + Managed                           1.64    False
# MTF ~ MATsoil + Humidity + PFT + Managed            1.52    False
# MTF ~ MATsoil + Managed                             1.60     True
# MTF ~ MAT + Managed                                 1.68     True
# MTF ~ MAT + Humidity + Managed                      1.67    False
# MTF ~ MATsoil + Humidity + Managed                  1.60    False
# MTF ~ PFT + DBH_mean + Managed                      1.65    False
# MTF ~ Humidity + PFT + DBH_mean + Managed           1.64    False
# MTF ~ DBH_mean + Managed                            1.67    False
# MTF ~ PFT + Managed                                 1.67    False
# MTF ~ MATsoil + PFT                                 1.31    False
# MTF ~ Humidity + DBH_mean + Managed                 1.67    False
# MTF ~ Humidity + PFT + Managed                      1.66    False
# MTF ~ MATsoil + Humidity + PFT                      1.31    False
# MTF ~ Managed                                       1.74     True
# MTF ~ MATsoil                                       1.35     True
# MTF ~ MAT + Humidity + PFT                          1.36    False
# MTF ~ Humidity + Managed                            1.72    False
# MTF ~ CDI + DBH_mean                                1.42    False
# MTF ~ MATsoil + Humidity                            1.36    False
# MTF ~ MAT + PFT                                     1.37    False
# MTF ~ CDI + PFT + DBH_mean                          1.42    False
# MTF ~ MAT + Humidity                                1.41    False
# MTF ~ CDI                                           1.47     True
# MTF ~ CDI + PFT                                     1.45    False
# MTF ~ MAT                                           1.42     True
# MTF ~ Humidity + PFT                                1.36    False
# MTF ~ Humidity + PFT + DBH_mean                     1.33    False
# MTF ~ PFT + DBH_mean                                1.37    False
# MTF ~ PFT                                           1.40    False
# MTF ~ Humidity + DBH_mean                           1.29    False
# MTF ~ DBH_mean                                      1.32    False
# MTF ~ Humidity                                      1.35    False
#
#                                                                   prms_fail  \
# MTF ~ MAT + DBH_mean + Managed
# MTF ~ MAT + PFT + DBH_mean + Managed                                    PFT
# MTF ~ MAT + Humidity + DBH_mean + Managed                          Humidity
# MTF ~ MAT + Humidity + PFT + DBH_mean + Managed               Humidity, PFT
# MTF ~ MATsoil + DBH_mean + Managed
# MTF ~ MATsoil + PFT + DBH_mean + Managed                                PFT
# MTF ~ MATsoil + Humidity + PFT + DBH_mean + Man...            Humidity, PFT
# MTF ~ MATsoil + Humidity + DBH_mean + Managed                      Humidity
# MTF ~ MATsoil + PFT + DBH_mean                                          PFT
# MTF ~ MATsoil + DBH_mean
# MTF ~ MATsoil + Humidity + PFT + DBH_mean                     Humidity, PFT
# MTF ~ MAT + Humidity + PFT + DBH_mean                         Humidity, PFT
# MTF ~ MATsoil + Humidity + DBH_mean                                Humidity
# MTF ~ MAT + Humidity + DBH_mean                                    Humidity
# MTF ~ CDI + DBH_mean + Managed                                     DBH_mean
# MTF ~ MAT + PFT + DBH_mean                                              PFT
# MTF ~ CDI + PFT + DBH_mean + Managed                          PFT, DBH_mean
# MTF ~ MAT + DBH_mean
# MTF ~ MATsoil + PFT + Managed                                           PFT
# MTF ~ MAT + PFT + Managed                                               PFT
# MTF ~ MAT + Humidity + PFT + Managed                          Humidity, PFT
# MTF ~ CDI + Managed
# MTF ~ CDI + PFT + Managed                                          CDI, PFT
# MTF ~ MATsoil + Humidity + PFT + Managed                      Humidity, PFT
# MTF ~ MATsoil + Managed
# MTF ~ MAT + Managed
# MTF ~ MAT + Humidity + Managed                                     Humidity
# MTF ~ MATsoil + Humidity + Managed                                 Humidity
# MTF ~ PFT + DBH_mean + Managed                                PFT, DBH_mean
# MTF ~ Humidity + PFT + DBH_mean + Managed           Humidity, PFT, DBH_mean
# MTF ~ DBH_mean + Managed                                           DBH_mean
# MTF ~ PFT + Managed                                                     PFT
# MTF ~ MATsoil + PFT                                                     PFT
# MTF ~ Humidity + DBH_mean + Managed                      Humidity, DBH_mean
# MTF ~ Humidity + PFT + Managed                                Humidity, PFT
# MTF ~ MATsoil + Humidity + PFT                                Humidity, PFT
# MTF ~ Managed
# MTF ~ MATsoil
# MTF ~ MAT + Humidity + PFT                                    Humidity, PFT
# MTF ~ Humidity + Managed                                           Humidity
# MTF ~ CDI + DBH_mean                                               DBH_mean
# MTF ~ MATsoil + Humidity                                           Humidity
# MTF ~ MAT + PFT                                                         PFT
# MTF ~ CDI + PFT + DBH_mean                                    PFT, DBH_mean
# MTF ~ MAT + Humidity                                               Humidity
# MTF ~ CDI
# MTF ~ CDI + PFT                                                         PFT
# MTF ~ MAT
# MTF ~ Humidity + PFT                                          Humidity, PFT
# MTF ~ Humidity + PFT + DBH_mean                     Humidity, PFT, DBH_mean
# MTF ~ PFT + DBH_mean                                          PFT, DBH_mean
# MTF ~ PFT                                                               PFT
# MTF ~ Humidity + DBH_mean                                Humidity, DBH_mean
# MTF ~ DBH_mean                                                     DBH_mean
# MTF ~ Humidity                                                     Humidity
#
#                                                     N_obs  ID MTF_basis  \
# MTF ~ MAT + DBH_mean + Managed                       64.0   0     cmass
# MTF ~ MAT + PFT + DBH_mean + Managed                 64.0   1     cmass
# MTF ~ MAT + Humidity + DBH_mean + Managed            64.0   2     cmass
# MTF ~ MAT + Humidity + PFT + DBH_mean + Managed      64.0   3     cmass
# MTF ~ MATsoil + DBH_mean + Managed                   64.0   4     cmass
# MTF ~ MATsoil + PFT + DBH_mean + Managed             64.0   5     cmass
# MTF ~ MATsoil + Humidity + PFT + DBH_mean + Man...   64.0   6     cmass
# MTF ~ MATsoil + Humidity + DBH_mean + Managed        64.0   7     cmass
# MTF ~ MATsoil + PFT + DBH_mean                       64.0   8     cmass
# MTF ~ MATsoil + DBH_mean                             64.0   9     cmass
# MTF ~ MATsoil + Humidity + PFT + DBH_mean            64.0  10     cmass
# MTF ~ MAT + Humidity + PFT + DBH_mean                64.0  11     cmass
# MTF ~ MATsoil + Humidity + DBH_mean                  64.0  12     cmass
# MTF ~ MAT + Humidity + DBH_mean                      64.0  13     cmass
# MTF ~ CDI + DBH_mean + Managed                       64.0  14     cmass
# MTF ~ MAT + PFT + DBH_mean                           64.0  15     cmass
# MTF ~ CDI + PFT + DBH_mean + Managed                 64.0  16     cmass
# MTF ~ MAT + DBH_mean                                 64.0  17     cmass
# MTF ~ MATsoil + PFT + Managed                        64.0  18     cmass
# MTF ~ MAT + PFT + Managed                            64.0  19     cmass
# MTF ~ MAT + Humidity + PFT + Managed                 64.0  20     cmass
# MTF ~ CDI + Managed                                  64.0  21     cmass
# MTF ~ CDI + PFT + Managed                            64.0  22     cmass
# MTF ~ MATsoil + Humidity + PFT + Managed             64.0  23     cmass
# MTF ~ MATsoil + Managed                              64.0  24     cmass
# MTF ~ MAT + Managed                                  64.0  25     cmass
# MTF ~ MAT + Humidity + Managed                       64.0  26     cmass
# MTF ~ MATsoil + Humidity + Managed                   64.0  27     cmass
# MTF ~ PFT + DBH_mean + Managed                       64.0  28     cmass
# MTF ~ Humidity + PFT + DBH_mean + Managed            64.0  29     cmass
# MTF ~ DBH_mean + Managed                             64.0  30     cmass
# MTF ~ PFT + Managed                                  64.0  31     cmass
# MTF ~ MATsoil + PFT                                  64.0  32     cmass
# MTF ~ Humidity + DBH_mean + Managed                  64.0  33     cmass
# MTF ~ Humidity + PFT + Managed                       64.0  34     cmass
# MTF ~ MATsoil + Humidity + PFT                       64.0  35     cmass
# MTF ~ Managed                                        64.0  36     cmass
# MTF ~ MATsoil                                        64.0  37     cmass
# MTF ~ MAT + Humidity + PFT                           64.0  38     cmass
# MTF ~ Humidity + Managed                             64.0  39     cmass
# MTF ~ CDI + DBH_mean                                 64.0  40     cmass
# MTF ~ MATsoil + Humidity                             64.0  41     cmass
# MTF ~ MAT + PFT                                      64.0  42     cmass
# MTF ~ CDI + PFT + DBH_mean                           64.0  43     cmass
# MTF ~ MAT + Humidity                                 64.0  44     cmass
# MTF ~ CDI                                            64.0  45     cmass
# MTF ~ CDI + PFT                                      64.0  46     cmass
# MTF ~ MAT                                            64.0  47     cmass
# MTF ~ Humidity + PFT                                 64.0  48     cmass
# MTF ~ Humidity + PFT + DBH_mean                      64.0  49     cmass
# MTF ~ PFT + DBH_mean                                 64.0  50     cmass
# MTF ~ PFT                                            64.0  51     cmass
# MTF ~ Humidity + DBH_mean                            64.0  52     cmass
# MTF ~ DBH_mean                                       64.0  53     cmass
# MTF ~ Humidity                                       64.0  54     cmass
#
#                                                       climate  \
# MTF ~ MAT + DBH_mean + Managed                      CRUNCEPv7
# MTF ~ MAT + PFT + DBH_mean + Managed                CRUNCEPv7
# MTF ~ MAT + Humidity + DBH_mean + Managed           CRUNCEPv7
# MTF ~ MAT + Humidity + PFT + DBH_mean + Managed     CRUNCEPv7
# MTF ~ MATsoil + DBH_mean + Managed                  CRUNCEPv7
# MTF ~ MATsoil + PFT + DBH_mean + Managed            CRUNCEPv7
# MTF ~ MATsoil + Humidity + PFT + DBH_mean + Man...  CRUNCEPv7
# MTF ~ MATsoil + Humidity + DBH_mean + Managed       CRUNCEPv7
# MTF ~ MATsoil + PFT + DBH_mean                      CRUNCEPv7
# MTF ~ MATsoil + DBH_mean                            CRUNCEPv7
# MTF ~ MATsoil + Humidity + PFT + DBH_mean           CRUNCEPv7
# MTF ~ MAT + Humidity + PFT + DBH_mean               CRUNCEPv7
# MTF ~ MATsoil + Humidity + DBH_mean                 CRUNCEPv7
# MTF ~ MAT + Humidity + DBH_mean                     CRUNCEPv7
# MTF ~ CDI + DBH_mean + Managed                      CRUNCEPv7
# MTF ~ MAT + PFT + DBH_mean                          CRUNCEPv7
# MTF ~ CDI + PFT + DBH_mean + Managed                CRUNCEPv7
# MTF ~ MAT + DBH_mean                                CRUNCEPv7
# MTF ~ MATsoil + PFT + Managed                       CRUNCEPv7
# MTF ~ MAT + PFT + Managed                           CRUNCEPv7
# MTF ~ MAT + Humidity + PFT + Managed                CRUNCEPv7
# MTF ~ CDI + Managed                                 CRUNCEPv7
# MTF ~ CDI + PFT + Managed                           CRUNCEPv7
# MTF ~ MATsoil + Humidity + PFT + Managed            CRUNCEPv7
# MTF ~ MATsoil + Managed                             CRUNCEPv7
# MTF ~ MAT + Managed                                 CRUNCEPv7
# MTF ~ MAT + Humidity + Managed                      CRUNCEPv7
# MTF ~ MATsoil + Humidity + Managed                  CRUNCEPv7
# MTF ~ PFT + DBH_mean + Managed                      CRUNCEPv7
# MTF ~ Humidity + PFT + DBH_mean + Managed           CRUNCEPv7
# MTF ~ DBH_mean + Managed                            CRUNCEPv7
# MTF ~ PFT + Managed                                 CRUNCEPv7
# MTF ~ MATsoil + PFT                                 CRUNCEPv7
# MTF ~ Humidity + DBH_mean + Managed                 CRUNCEPv7
# MTF ~ Humidity + PFT + Managed                      CRUNCEPv7
# MTF ~ MATsoil + Humidity + PFT                      CRUNCEPv7
# MTF ~ Managed                                       CRUNCEPv7
# MTF ~ MATsoil                                       CRUNCEPv7
# MTF ~ MAT + Humidity + PFT                          CRUNCEPv7
# MTF ~ Humidity + Managed                            CRUNCEPv7
# MTF ~ CDI + DBH_mean                                CRUNCEPv7
# MTF ~ MATsoil + Humidity                            CRUNCEPv7
# MTF ~ MAT + PFT                                     CRUNCEPv7
# MTF ~ CDI + PFT + DBH_mean                          CRUNCEPv7
# MTF ~ MAT + Humidity                                CRUNCEPv7
# MTF ~ CDI                                           CRUNCEPv7
# MTF ~ CDI + PFT                                     CRUNCEPv7
# MTF ~ MAT                                           CRUNCEPv7
# MTF ~ Humidity + PFT                                CRUNCEPv7
# MTF ~ Humidity + PFT + DBH_mean                     CRUNCEPv7
# MTF ~ PFT + DBH_mean                                CRUNCEPv7
# MTF ~ PFT                                           CRUNCEPv7
# MTF ~ Humidity + DBH_mean                           CRUNCEPv7
# MTF ~ DBH_mean                                      CRUNCEPv7
# MTF ~ Humidity                                      CRUNCEPv7
#
#                                                     standardised_covars
# MTF ~ MAT + DBH_mean + Managed                                    False
# MTF ~ MAT + PFT + DBH_mean + Managed                              False
# MTF ~ MAT + Humidity + DBH_mean + Managed                         False
# MTF ~ MAT + Humidity + PFT + DBH_mean + Managed                   False
# MTF ~ MATsoil + DBH_mean + Managed                                False
# MTF ~ MATsoil + PFT + DBH_mean + Managed                          False
# MTF ~ MATsoil + Humidity + PFT + DBH_mean + Man...                False
# MTF ~ MATsoil + Humidity + DBH_mean + Managed                     False
# MTF ~ MATsoil + PFT + DBH_mean                                    False
# MTF ~ MATsoil + DBH_mean                                          False
# MTF ~ MATsoil + Humidity + PFT + DBH_mean                         False
# MTF ~ MAT + Humidity + PFT + DBH_mean                             False
# MTF ~ MATsoil + Humidity + DBH_mean                               False
# MTF ~ MAT + Humidity + DBH_mean                                   False
# MTF ~ CDI + DBH_mean + Managed                                    False
# MTF ~ MAT + PFT + DBH_mean                                        False
# MTF ~ CDI + PFT + DBH_mean + Managed                              False
# MTF ~ MAT + DBH_mean                                              False
# MTF ~ MATsoil + PFT + Managed                                     False
# MTF ~ MAT + PFT + Managed                                         False
# MTF ~ MAT + Humidity + PFT + Managed                              False
# MTF ~ CDI + Managed                                               False
# MTF ~ CDI + PFT + Managed                                         False
# MTF ~ MATsoil + Humidity + PFT + Managed                          False
# MTF ~ MATsoil + Managed                                           False
# MTF ~ MAT + Managed                                               False
# MTF ~ MAT + Humidity + Managed                                    False
# MTF ~ MATsoil + Humidity + Managed                                False
# MTF ~ PFT + DBH_mean + Managed                                    False
# MTF ~ Humidity + PFT + DBH_mean + Managed                         False
# MTF ~ DBH_mean + Managed                                          False
# MTF ~ PFT + Managed                                               False
# MTF ~ MATsoil + PFT                                               False
# MTF ~ Humidity + DBH_mean + Managed                               False
# MTF ~ Humidity + PFT + Managed                                    False
# MTF ~ MATsoil + Humidity + PFT                                    False
# MTF ~ Managed                                                     False
# MTF ~ MATsoil                                                     False
# MTF ~ MAT + Humidity + PFT                                        False
# MTF ~ Humidity + Managed                                          False
# MTF ~ CDI + DBH_mean                                              False
# MTF ~ MATsoil + Humidity                                          False
# MTF ~ MAT + PFT                                                   False
# MTF ~ CDI + PFT + DBH_mean                                        False
# MTF ~ MAT + Humidity                                              False
# MTF ~ CDI                                                         False
# MTF ~ CDI + PFT                                                   False
# MTF ~ MAT                                                         False
# MTF ~ Humidity + PFT                                              False
# MTF ~ Humidity + PFT + DBH_mean                                   False
# MTF ~ PFT + DBH_mean                                              False
# MTF ~ PFT                                                         False
# MTF ~ Humidity + DBH_mean                                         False
# MTF ~ DBH_mean                                                    False
# MTF ~ Humidity                                                    False
# #------------------------------#
# #   Standardising covariates   #
# #------------------------------#
#
#
# ==============================
#
#              count
#
# ==============================
#
# CDI 0.3247904229919729
# DBH_mean 26.067421928598616
# Humidity 1.7465289169311524
# MAP 870.7375
# MAT 4.7109375
# MATsoil 5.639062529429793
# Managed 0.28125
# PFT 0.921875
#                                                    r2    AIC  d_AIC   RMSE  \
# MTF ~ MAT + PFT + DBH_mean + Managed             0.37  147.5    0.5  23.34
# MTF ~ MAT + MAP + PFT + DBH_mean + Managed       0.37  147.9    0.9  22.17
# MTF ~ MAT + DBH_mean + Managed                   0.36  147.0    0.0  23.47
# MTF ~ MAT + MAP + DBH_mean + Managed             0.36  147.6    0.6  22.39
# MTF ~ MAT + Humidity + PFT + DBH_mean + Managed  0.36  149.1    2.1  23.34
# ...                                               ...    ...    ...    ...
# MTF ~ MAP + PFT + DBH_mean                       0.04  173.4   26.4  27.14
# MTF ~ PFT                                        0.03  171.6   24.6  27.80
# MTF ~ DBH_mean                                   0.02  172.5   25.5  27.38
# MTF ~ Humidity + DBH_mean                        0.02  173.2   26.2  27.20
# MTF ~ Humidity                                   0.01  173.3   26.3  28.13
#
#                                                   DWT prms_sig  \
# MTF ~ MAT + PFT + DBH_mean + Managed             1.60    False
# MTF ~ MAT + MAP + PFT + DBH_mean + Managed       1.54    False
# MTF ~ MAT + DBH_mean + Managed                   1.62     True
# MTF ~ MAT + MAP + DBH_mean + Managed             1.57    False
# MTF ~ MAT + Humidity + PFT + DBH_mean + Managed  1.60    False
# ...                                               ...      ...
# MTF ~ MAP + PFT + DBH_mean                       1.47    False
# MTF ~ PFT                                        1.47    False
# MTF ~ DBH_mean                                   1.38    False
# MTF ~ Humidity + DBH_mean                        1.35    False
# MTF ~ Humidity                                   1.42    False
#
#                                                           prms_fail  N_obs  \
# MTF ~ MAT + PFT + DBH_mean + Managed                            PFT   64.0
# MTF ~ MAT + MAP + PFT + DBH_mean + Managed                 MAP, PFT   64.0
# MTF ~ MAT + DBH_mean + Managed                                        64.0
# MTF ~ MAT + MAP + DBH_mean + Managed                            MAP   64.0
# MTF ~ MAT + Humidity + PFT + DBH_mean + Managed       Humidity, PFT   64.0
# ...                                                             ...    ...
# MTF ~ MAP + PFT + DBH_mean                       MAP, PFT, DBH_mean   64.0
# MTF ~ PFT                                                       PFT   64.0
# MTF ~ DBH_mean                                             DBH_mean   64.0
# MTF ~ Humidity + DBH_mean                        Humidity, DBH_mean   64.0
# MTF ~ Humidity                                             Humidity   64.0
#
#                                                  ID MTF_basis    climate  \
# MTF ~ MAT + PFT + DBH_mean + Managed              0     count  CRUNCEPv7
# MTF ~ MAT + MAP + PFT + DBH_mean + Managed        1     count  CRUNCEPv7
# MTF ~ MAT + DBH_mean + Managed                    2     count  CRUNCEPv7
# MTF ~ MAT + MAP + DBH_mean + Managed              3     count  CRUNCEPv7
# MTF ~ MAT + Humidity + PFT + DBH_mean + Managed   4     count  CRUNCEPv7
# ...                                              ..       ...        ...
# MTF ~ MAP + PFT + DBH_mean                       71     count  CRUNCEPv7
# MTF ~ PFT                                        72     count  CRUNCEPv7
# MTF ~ DBH_mean                                   73     count  CRUNCEPv7
# MTF ~ Humidity + DBH_mean                        74     count  CRUNCEPv7
# MTF ~ Humidity                                   75     count  CRUNCEPv7
#
#                                                  standardised_covars
# MTF ~ MAT + PFT + DBH_mean + Managed                            True
# MTF ~ MAT + MAP + PFT + DBH_mean + Managed                      True
# MTF ~ MAT + DBH_mean + Managed                                  True
# MTF ~ MAT + MAP + DBH_mean + Managed                            True
# MTF ~ MAT + Humidity + PFT + DBH_mean + Managed                 True
# ...                                                              ...
# MTF ~ MAP + PFT + DBH_mean                                      True
# MTF ~ PFT                                                       True
# MTF ~ DBH_mean                                                  True
# MTF ~ Humidity + DBH_mean                                       True
# MTF ~ Humidity                                                  True
#
# [76 rows x 12 columns]
# ==============================
#
#              cmass
#
# ==============================
#
# CDI 0.3247904229919729
# DBH_mean 26.067421928598616
# Humidity 1.7465289169311524
# MAP 870.7375
# MAT 4.7109375
# MATsoil 5.639062529429793
# Managed 0.28125
# PFT 0.921875
#                                               r2    AIC  d_AIC   RMSE   DWT  \
# MTF ~ MAT + MAP + PFT + DBH_mean + Managed  0.43  151.9    1.1  46.92  1.62
# MTF ~ MAT + DBH_mean + Managed              0.42  150.8    0.0  49.30  1.71
# MTF ~ MAT + PFT + DBH_mean + Managed        0.42  151.3    0.5  48.99  1.67
# MTF ~ MAT + MAP + DBH_mean + Managed        0.42  151.6    0.8  47.40  1.67
# MTF ~ MAT + Humidity + DBH_mean + Managed   0.42  152.1    1.3  49.33  1.71
# ...                                          ...    ...    ...    ...   ...
# MTF ~ MAP + PFT + DBH_mean                  0.04  183.2   32.4  56.09  1.42
# MTF ~ PFT                                   0.03  181.4   30.6  56.93  1.40
# MTF ~ Humidity + DBH_mean                   0.02  183.0   32.2  56.13  1.29
# MTF ~ DBH_mean                              0.01  182.7   31.9  56.51  1.32
# MTF ~ Humidity                              0.01  182.7   31.9  57.56  1.35
#
#                                            prms_sig           prms_fail  \
# MTF ~ MAT + MAP + PFT + DBH_mean + Managed    False            MAP, PFT
# MTF ~ MAT + DBH_mean + Managed                 True
# MTF ~ MAT + PFT + DBH_mean + Managed          False                 PFT
# MTF ~ MAT + MAP + DBH_mean + Managed          False                 MAP
# MTF ~ MAT + Humidity + DBH_mean + Managed     False            Humidity
# ...                                             ...                 ...
# MTF ~ MAP + PFT + DBH_mean                    False  MAP, PFT, DBH_mean
# MTF ~ PFT                                     False                 PFT
# MTF ~ Humidity + DBH_mean                     False  Humidity, DBH_mean
# MTF ~ DBH_mean                                False            DBH_mean
# MTF ~ Humidity                                False            Humidity
#
#                                             N_obs  ID MTF_basis    climate  \
# MTF ~ MAT + MAP + PFT + DBH_mean + Managed   64.0   0     cmass  CRUNCEPv7
# MTF ~ MAT + DBH_mean + Managed               64.0   1     cmass  CRUNCEPv7
# MTF ~ MAT + PFT + DBH_mean + Managed         64.0   2     cmass  CRUNCEPv7
# MTF ~ MAT + MAP + DBH_mean + Managed         64.0   3     cmass  CRUNCEPv7
# MTF ~ MAT + Humidity + DBH_mean + Managed    64.0   4     cmass  CRUNCEPv7
# ...                                           ...  ..       ...        ...
# MTF ~ MAP + PFT + DBH_mean                   64.0  71     cmass  CRUNCEPv7
# MTF ~ PFT                                    64.0  72     cmass  CRUNCEPv7
# MTF ~ Humidity + DBH_mean                    64.0  73     cmass  CRUNCEPv7
# MTF ~ DBH_mean                               64.0  74     cmass  CRUNCEPv7
# MTF ~ Humidity                               64.0  75     cmass  CRUNCEPv7
#
#                                             standardised_covars
# MTF ~ MAT + MAP + PFT + DBH_mean + Managed                 True
# MTF ~ MAT + DBH_mean + Managed                             True
# MTF ~ MAT + PFT + DBH_mean + Managed                       True
# MTF ~ MAT + MAP + DBH_mean + Managed                       True
# MTF ~ MAT + Humidity + DBH_mean + Managed                  True
# ...                                                         ...
# MTF ~ MAP + PFT + DBH_mean                                 True
# MTF ~ PFT                                                  True
# MTF ~ Humidity + DBH_mean                                  True
# MTF ~ DBH_mean                                             True
# MTF ~ Humidity                                             True
#
# [76 rows x 12 columns]
