# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# Load libraries
import numpy as np
import pandas as pd
import sys
import os
import pickle

from classes import boundaries as bd
from classes import snag_MTF_func as sg

# %config Completer.use_jedi = False 




#--- Notebook run settings
run = 'command line' # 'manual' 'command line'
#run = 'manual'

# Settings for the multiple linear regression model (MLR)
#--- Arguments
if run == 'command line':
    # Read command line arguments
    arguments = os.environ['NB_ARGS']
    climate_data, alpha, date_exp_str, remove_data = arguments.split(',')
    
    alpha              = float(alpha)   
    remove_data        = bool(remove_data)
    
elif run == 'manual':
    # Enter arguments manually 
    alpha              = 0.05
    date_exp_str       = '230118_Moisture'
    climate_data_list  = ['CRUclim','CRUNCEPv7','CHELSA30s','WorldClim30s','WorldClim10m',]
    climate_data       = climate_data_list[1]
    remove_data        = True
print(date_exp_str, alpha, remove_data,climate_data)
# Out:
# 230118_Moisture 0.05 True CRUNCEPv7

# %%
#---------------#
#  Import data  #
#---------------#
mtf_type = ['count','cmass']

#--- Experiments
with open('spe_reg_results/'+date_exp_str+'_Spe_reg_experiments_list.pkl', 'rb') as f:
    experiments = pickle.load(f)    
# Isolate unique variables in experiment list for standardisation of covars
strings     = [i.replace('MTF ~ ','') for i in experiments]
strings     = [i.split(' * ')[0] for i in strings]
strings     = [i.split(' + ') for i in strings]
flat_list   = [item for sublist in strings for item in sublist]
var_list_in = np.unique(flat_list)    

# Data        
cols = ['Reference','Continent','Country','Site name','MTF','MTF basis', 'DBH mean','MAP','Insects','MATsoil',
        'Wood durability','CN_ratio','CDI','Managed','Fire','Mortality','MAT','Humidity','PFT',
        'Soil_water','Soil_water_max']    
    
species_mtf = sg.MTF_database_import('data/MTF_database.xlsx','Species_MTF',engine=True)
species_mtf.loc[species_mtf['Site name'].isna(),['Site name']] = ''
species_mtf.loc[species_mtf['Y coords'].isna(),['Y coords']] = ''
species_mtf.loc[species_mtf['X coords'].isna(),['X coords']] = ''
species_mtf_cp = species_mtf.copy()
species_mtf['MAT'] = species_mtf[(climate_data,'MAT')]
species_mtf['MAP'] = species_mtf[(climate_data,'MAP')]
mtf = species_mtf.loc[:, cols].copy()

mtf.columns = mtf.columns.get_level_values(0)
mtf_cp = mtf.copy()


mtf_check = mtf.copy()   

#--- Remove data - based on cooks distance and inapplicable 
if remove_data:
    mtf = mtf[~(mtf.Reference == 'Ritchie2014EstablishmentForest')].copy()
    mtf = mtf[(mtf.Reference != 'Campbell2016CarbonStates')].copy()
    
    if 'FireOnly' in date_exp_str:
        mtf = mtf[(mtf.Fire == 1)]
    
    if 'NoFire' in date_exp_str:
        mtf = mtf[(mtf.Fire == 0)]
    
    if 'NoInsectsFire' in date_exp_str:
        mtf = mtf[(mtf.Fire == 0) & (mtf.Insects == 0)]

        
#--------------------#
#   Transform data   #
#--------------------#
mtf.loc[:, 'DBH mean'] = pd.to_numeric(mtf['DBH mean'])
mtf.loc[:, 'MTF']      = mtf.loc[:, 'MTF'].apply(np.log)

# Drop subset based on data subset
if 'WoodQ' in date_exp_str:
    mtf = mtf.dropna(subset=['DBH mean','MAT','Humidity','PFT','Wood durability','CN_ratio']) 
elif 'Moisture' in date_exp_str:
    mtf = mtf.dropna(subset=['DBH mean','MAT','Humidity','PFT','Soil_water', 'Soil_water_max'])  
elif 'Management' in date_exp_str:
    mtf = mtf.dropna(subset=['DBH mean','MAT','Humidity','PFT','Managed']) 
else:
    mtf = mtf.dropna(subset=['DBH mean','MAT','Humidity','PFT']) 

# Rename columns to work with OLS
cols             = mtf.columns.values
index_dbh        = mtf.columns.get_loc('DBH mean')
index_wq         = mtf.columns.get_loc('Wood durability')
cols[index_wq]   = 'Wood_durability'
cols[index_dbh]  = 'DBH_mean'
mtf.columns      = cols


#--- Seperate date according to MTF type
mtf_count = mtf[(mtf['MTF basis'] == 'count') & (mtf.MTF.notnull())].copy()
mtf_cmass = mtf[(mtf['MTF basis'] == 'cmass') & (mtf.MTF.notnull())].copy()
mtf_c     = mtf[(mtf['MTF basis'] == 'c') & (mtf.MTF.notnull())].copy()   

# Combine data into list for loop
data = [mtf_count, mtf_cmass]

print(len(mtf_count))
# Out:
# 109

# %%
standardise_covars_list = [False, True]

# Initialise storage
reg_results = np.empty((len(standardise_covars_list),len(mtf_type),2), dtype='object') 

for st in range(len(standardise_covars_list)):
    standardise_covars = standardise_covars_list[st]
    if standardise_covars:
        bd.print_header('Standardising covariates')
    for t,tp in enumerate(mtf_type):
        bd.print_TITLE(tp)

        mtf_reg = data[t].copy()


        if standardise_covars:
            
            for var in var_list_in:
                print(var, mtf_reg.loc[:,var].mean())
                if mtf_reg.loc[:,var].std() == 0:
                    print('\n'+tp+'t!\nSetting {} to 0 because Std is 0, i.e. standardisation fails!\n'.format(
                        var))
                    mtf_reg.loc[:,var] = 0
                else:
                    mtf_reg.loc[:,var] = ((mtf_reg.loc[:,var] - mtf_reg.loc[:,var].mean()) /
                                                mtf_reg.loc[:,var].std())  

        # Run regressions
        res_table, result_objs = sg.regression_wrapper(mtf_reg, experiments[:],alpha, tp, 
                                                       climate_data, standardise_covars)
        
        reg_results[st,t,0] = res_table  # Ranking of models
        reg_results[st,t,1] = result_objs # regression objects for each correspoding model (regression metrics & parameters)

        display(res_table)

storage_string = 'spe_reg_results/'+date_exp_str+'_SPE_'+str(alpha)+'_'+climate_data+'.pkl'
with open(storage_string, 'wb') as f:
    pickle.dump(reg_results, f)
# Out:
# ==============================
#
#              count
#
# ==============================
#                                              r2    AIC  d_AIC   RMSE   DWT  \
# MTF ~ MAT + Humidity + PFT + DBH_mean      0.60  205.2    0.0  26.62  1.26
# MTF ~ MATsoil + Humidity + PFT + DBH_mean  0.52  224.0   18.8  28.54  1.07
# MTF ~ MAT + PFT + DBH_mean                 0.51  225.1   19.9  29.42  0.98
# MTF ~ MAT + DBH_mean                       0.50  227.0   21.8  29.10  0.90
# MTF ~ Humidity + PFT + DBH_mean            0.48  231.5   26.3  28.58  1.12
# MTF ~ MATsoil + DBH_mean                   0.47  234.4   29.2  31.00  0.81
# MTF ~ MATsoil + PFT + DBH_mean             0.47  235.1   29.9  31.21  0.85
# MTF ~ Humidity + DBH_mean                  0.46  236.0   30.8  28.25  0.95
# MTF ~ PFT + DBH_mean                       0.38  251.3   46.1  32.30  0.83
# MTF ~ DBH_mean                             0.36  253.0   47.8  31.88  0.76
# MTF ~ MAT + Soil_water_max + PFT           0.12  289.4   84.2  41.79  0.98
# MTF ~ MAT + Soil_water + PFT               0.12  289.5   84.3  41.78  0.98
# MTF ~ MATsoil + Soil_water_max + PFT       0.11  290.8   85.6  41.82  0.96
# MTF ~ CDI                                  0.05  295.8   90.6  42.51  0.84
# MTF ~ MATsoil                              0.02  299.7   94.5  42.81  0.76
# MTF ~ MATsoil + Soil_water                 0.02  300.7   95.5  42.72  0.78
# MTF ~ MAT                                  0.01  300.6   95.4  42.81  0.77
# MTF ~ MATsoil + Soil_water_max             0.01  301.7   96.5  42.81  0.76
# MTF ~ MAT + Soil_water                     0.01  301.9   96.7  42.73  0.80
# MTF ~ Soil_water                          -0.00  301.8   96.6  42.68  0.83
# MTF ~ MAT + Soil_water_max                 0.00  302.5   97.3  42.83  0.76
# MTF ~ Soil_water_max                      -0.01  302.6   97.4  42.76  0.80
#
#                                           prms_sig                prms_fail  \
# MTF ~ MAT + Humidity + PFT + DBH_mean         True
# MTF ~ MATsoil + Humidity + PFT + DBH_mean    False                      PFT
# MTF ~ MAT + PFT + DBH_mean                   False                      PFT
# MTF ~ MAT + DBH_mean                          True
# MTF ~ Humidity + PFT + DBH_mean               True
# MTF ~ MATsoil + DBH_mean                      True
# MTF ~ MATsoil + PFT + DBH_mean               False                      PFT
# MTF ~ Humidity + DBH_mean                     True
# MTF ~ PFT + DBH_mean                         False                      PFT
# MTF ~ DBH_mean                                True
# MTF ~ MAT + Soil_water_max + PFT             False      MAT, Soil_water_max
# MTF ~ MAT + Soil_water + PFT                 False          MAT, Soil_water
# MTF ~ MATsoil + Soil_water_max + PFT         False  MATsoil, Soil_water_max
# MTF ~ CDI                                     True
# MTF ~ MATsoil                                False                  MATsoil
# MTF ~ MATsoil + Soil_water                   False      MATsoil, Soil_water
# MTF ~ MAT                                    False                      MAT
# MTF ~ MATsoil + Soil_water_max               False  MATsoil, Soil_water_max
# MTF ~ MAT + Soil_water                       False          MAT, Soil_water
# MTF ~ Soil_water                             False               Soil_water
# MTF ~ MAT + Soil_water_max                   False      MAT, Soil_water_max
# MTF ~ Soil_water_max                         False           Soil_water_max
#
#                                            N_obs  ID MTF_basis    climate  \
# MTF ~ MAT + Humidity + PFT + DBH_mean      109.0   0     count  CRUNCEPv7
# MTF ~ MATsoil + Humidity + PFT + DBH_mean  109.0   1     count  CRUNCEPv7
# MTF ~ MAT + PFT + DBH_mean                 109.0   2     count  CRUNCEPv7
# MTF ~ MAT + DBH_mean                       109.0   3     count  CRUNCEPv7
# MTF ~ Humidity + PFT + DBH_mean            109.0   4     count  CRUNCEPv7
# MTF ~ MATsoil + DBH_mean                   109.0   5     count  CRUNCEPv7
# MTF ~ MATsoil + PFT + DBH_mean             109.0   6     count  CRUNCEPv7
# MTF ~ Humidity + DBH_mean                  109.0   7     count  CRUNCEPv7
# MTF ~ PFT + DBH_mean                       109.0   8     count  CRUNCEPv7
# MTF ~ DBH_mean                             109.0   9     count  CRUNCEPv7
# MTF ~ MAT + Soil_water_max + PFT           109.0  10     count  CRUNCEPv7
# MTF ~ MAT + Soil_water + PFT               109.0  11     count  CRUNCEPv7
# MTF ~ MATsoil + Soil_water_max + PFT       109.0  12     count  CRUNCEPv7
# MTF ~ CDI                                  109.0  13     count  CRUNCEPv7
# MTF ~ MATsoil                              109.0  14     count  CRUNCEPv7
# MTF ~ MATsoil + Soil_water                 109.0  15     count  CRUNCEPv7
# MTF ~ MAT                                  109.0  16     count  CRUNCEPv7
# MTF ~ MATsoil + Soil_water_max             109.0  17     count  CRUNCEPv7
# MTF ~ MAT + Soil_water                     109.0  18     count  CRUNCEPv7
# MTF ~ Soil_water                           109.0  19     count  CRUNCEPv7
# MTF ~ MAT + Soil_water_max                 109.0  20     count  CRUNCEPv7
# MTF ~ Soil_water_max                       109.0  21     count  CRUNCEPv7
#
#                                            standardised_covars
# MTF ~ MAT + Humidity + PFT + DBH_mean                    False
# MTF ~ MATsoil + Humidity + PFT + DBH_mean                False
# MTF ~ MAT + PFT + DBH_mean                               False
# MTF ~ MAT + DBH_mean                                     False
# MTF ~ Humidity + PFT + DBH_mean                          False
# MTF ~ MATsoil + DBH_mean                                 False
# MTF ~ MATsoil + PFT + DBH_mean                           False
# MTF ~ Humidity + DBH_mean                                False
# MTF ~ PFT + DBH_mean                                     False
# MTF ~ DBH_mean                                           False
# MTF ~ MAT + Soil_water_max + PFT                         False
# MTF ~ MAT + Soil_water + PFT                             False
# MTF ~ MATsoil + Soil_water_max + PFT                     False
# MTF ~ CDI                                                False
# MTF ~ MATsoil                                            False
# MTF ~ MATsoil + Soil_water                               False
# MTF ~ MAT                                                False
# MTF ~ MATsoil + Soil_water_max                           False
# MTF ~ MAT + Soil_water                                   False
# MTF ~ Soil_water                                         False
# MTF ~ MAT + Soil_water_max                               False
# MTF ~ Soil_water_max                                     False
# ==============================
#
#              cmass
#
# ==============================
#                                          r2    AIC  d_AIC   RMSE   DWT  \
# MTF ~ MAT + Humidity + PFT + DBH_mean  0.58  227.5    0.0  44.39  1.16
# MTF ~ MAT + Humidity + DBH_mean        0.55  232.4    4.9  44.78  1.01
# MTF ~ Humidity + PFT + DBH_mean        0.47  250.8   23.3  45.97  1.03
# MTF ~ MAT + DBH_mean                   0.47  250.9   23.4  48.14  0.83
# MTF ~ Humidity + DBH_mean              0.44  255.6   28.1  45.74  0.88
# MTF ~ MATsoil + DBH_mean               0.42  259.9   32.4  50.72  0.73
# MTF ~ MATsoil + PFT + DBH_mean         0.42  260.4   32.9  50.91  0.75
# MTF ~ DBH_mean                         0.34  274.2   46.7  51.23  0.69
# MTF ~ CDI                              0.04  313.9   86.4  66.22  0.75
# MTF ~ MATsoil                          0.01  317.5   90.0  66.65  0.68
# MTF ~ MAT                              0.01  317.8   90.3  66.65  0.70
# MTF ~ MATsoil + Soil_water_max         0.00  319.5   92.0  66.65  0.68
# MTF ~ MAT + Soil_water_max            -0.00  319.7   92.2  66.66  0.69
# MTF ~ Soil_water_max                  -0.01  319.7   92.2  66.52  0.73
#
#                                       prms_sig                prms_fail  \
# MTF ~ MAT + Humidity + PFT + DBH_mean     True
# MTF ~ MAT + Humidity + DBH_mean           True
# MTF ~ Humidity + PFT + DBH_mean           True
# MTF ~ MAT + DBH_mean                      True
# MTF ~ Humidity + DBH_mean                 True
# MTF ~ MATsoil + DBH_mean                  True
# MTF ~ MATsoil + PFT + DBH_mean           False                      PFT
# MTF ~ DBH_mean                            True
# MTF ~ CDI                                 True
# MTF ~ MATsoil                            False                  MATsoil
# MTF ~ MAT                                False                      MAT
# MTF ~ MATsoil + Soil_water_max           False  MATsoil, Soil_water_max
# MTF ~ MAT + Soil_water_max               False      MAT, Soil_water_max
# MTF ~ Soil_water_max                     False           Soil_water_max
#
#                                        N_obs  ID MTF_basis    climate  \
# MTF ~ MAT + Humidity + PFT + DBH_mean  109.0   0     cmass  CRUNCEPv7
# MTF ~ MAT + Humidity + DBH_mean        109.0   1     cmass  CRUNCEPv7
# MTF ~ Humidity + PFT + DBH_mean        109.0   2     cmass  CRUNCEPv7
# MTF ~ MAT + DBH_mean                   109.0   3     cmass  CRUNCEPv7
# MTF ~ Humidity + DBH_mean              109.0   4     cmass  CRUNCEPv7
# MTF ~ MATsoil + DBH_mean               109.0   5     cmass  CRUNCEPv7
# MTF ~ MATsoil + PFT + DBH_mean         109.0   6     cmass  CRUNCEPv7
# MTF ~ DBH_mean                         109.0   7     cmass  CRUNCEPv7
# MTF ~ CDI                              109.0   8     cmass  CRUNCEPv7
# MTF ~ MATsoil                          109.0   9     cmass  CRUNCEPv7
# MTF ~ MAT                              109.0  10     cmass  CRUNCEPv7
# MTF ~ MATsoil + Soil_water_max         109.0  11     cmass  CRUNCEPv7
# MTF ~ MAT + Soil_water_max             109.0  12     cmass  CRUNCEPv7
# MTF ~ Soil_water_max                   109.0  13     cmass  CRUNCEPv7
#
#                                        standardised_covars
# MTF ~ MAT + Humidity + PFT + DBH_mean                False
# MTF ~ MAT + Humidity + DBH_mean                      False
# MTF ~ Humidity + PFT + DBH_mean                      False
# MTF ~ MAT + DBH_mean                                 False
# MTF ~ Humidity + DBH_mean                            False
# MTF ~ MATsoil + DBH_mean                             False
# MTF ~ MATsoil + PFT + DBH_mean                       False
# MTF ~ DBH_mean                                       False
# MTF ~ CDI                                            False
# MTF ~ MATsoil                                        False
# MTF ~ MAT                                            False
# MTF ~ MATsoil + Soil_water_max                       False
# MTF ~ MAT + Soil_water_max                           False
# MTF ~ Soil_water_max                                 False
# #------------------------------#
# #   Standardising covariates   #
# #------------------------------#
#
#
# ==============================
#
#              count
#
# ==============================
#
# CDI 0.3095014336017726
# DBH_mean 30.43507263788527
# Humidity 1.7656554432160267
# MAP 907.3834862385319
# MAT 5.720183486238534
# MATsoil 6.546789010730358
# PFT 0.7614678899082569
# Soil_water 0.5596014192891777
# Soil_water_max 0.6797675443898648
#                                                r2    AIC  d_AIC   RMSE   DWT  \
# MTF ~ MAT + Humidity + PFT + DBH_mean        0.60  205.2    0.0  26.62  1.26
# MTF ~ MATsoil + Humidity + PFT + DBH_mean    0.52  224.0   18.8  28.54  1.07
# MTF ~ MAT + Soil_water_max + PFT + DBH_mean  0.52  224.1   18.9  28.57  1.00
# MTF ~ MAT + PFT + DBH_mean                   0.51  225.1   19.9  29.42  0.98
# MTF ~ MAT + Soil_water_max + DBH_mean        0.51  225.6   20.4  28.29  0.93
# MTF ~ MAT + MAP + PFT + DBH_mean             0.51  226.0   20.8  29.30  0.98
# MTF ~ MAT + Soil_water + PFT + DBH_mean      0.51  226.6   21.4  29.21  0.99
# MTF ~ MAT + DBH_mean                         0.50  227.0   21.8  29.10  0.90
# MTF ~ MAT + Soil_water + DBH_mean            0.50  227.4   22.2  28.83  0.93
# MTF ~ MAT + MAP + DBH_mean                   0.50  228.6   23.4  29.02  0.89
# MTF ~ Humidity + PFT + DBH_mean              0.48  231.5   26.3  28.58  1.12
# MTF ~ MATsoil + DBH_mean                     0.47  234.4   29.2  31.00  0.81
# MTF ~ MATsoil + PFT + DBH_mean               0.47  235.1   29.9  31.21  0.85
# MTF ~ Humidity + DBH_mean                    0.46  236.0   30.8  28.25  0.95
# MTF ~ PFT + DBH_mean                         0.38  251.3   46.1  32.30  0.83
# MTF ~ CDI + PFT + DBH_mean                   0.38  252.0   46.8  32.54  0.79
# MTF ~ CDI + DBH_mean                         0.37  251.7   46.5  32.43  0.73
# MTF ~ DBH_mean                               0.36  253.0   47.8  31.88  0.76
# MTF ~ MAT + Soil_water_max + PFT             0.12  289.4   84.2  41.79  0.98
# MTF ~ MAT + Soil_water + PFT                 0.12  289.5   84.3  41.78  0.98
# MTF ~ MATsoil + Soil_water_max + PFT         0.11  290.8   85.6  41.82  0.96
# MTF ~ CDI                                    0.05  295.8   90.6  42.51  0.84
# MTF ~ MATsoil                                0.02  299.7   94.5  42.81  0.76
# MTF ~ MATsoil + MAP                          0.02  300.7   95.5  42.70  0.78
# MTF ~ MATsoil + Soil_water                   0.02  300.7   95.5  42.72  0.78
# MTF ~ MAT                                    0.01  300.6   95.4  42.81  0.77
# MTF ~ MAP                                    0.01  300.8   95.6  42.63  0.83
# MTF ~ MAT + MAP                              0.01  301.7   96.5  42.69  0.80
# MTF ~ MATsoil + Soil_water_max               0.01  301.7   96.5  42.81  0.76
# MTF ~ MAT + Soil_water                       0.01  301.9   96.7  42.73  0.80
# MTF ~ Soil_water                            -0.00  301.8   96.6  42.68  0.83
# MTF ~ MAT + Soil_water_max                   0.00  302.5   97.3  42.83  0.76
# MTF ~ Soil_water_max                        -0.01  302.6   97.4  42.76  0.80
#
#                                             prms_sig                prms_fail  \
# MTF ~ MAT + Humidity + PFT + DBH_mean           True
# MTF ~ MATsoil + Humidity + PFT + DBH_mean      False                      PFT
# MTF ~ MAT + Soil_water_max + PFT + DBH_mean    False      Soil_water_max, PFT
# MTF ~ MAT + PFT + DBH_mean                     False                      PFT
# MTF ~ MAT + Soil_water_max + DBH_mean          False           Soil_water_max
# MTF ~ MAT + MAP + PFT + DBH_mean               False                      MAP
# MTF ~ MAT + Soil_water + PFT + DBH_mean        False          Soil_water, PFT
# MTF ~ MAT + DBH_mean                            True
# MTF ~ MAT + Soil_water + DBH_mean              False               Soil_water
# MTF ~ MAT + MAP + DBH_mean                     False                      MAP
# MTF ~ Humidity + PFT + DBH_mean                 True
# MTF ~ MATsoil + DBH_mean                        True
# MTF ~ MATsoil + PFT + DBH_mean                 False                      PFT
# MTF ~ Humidity + DBH_mean                       True
# MTF ~ PFT + DBH_mean                           False                      PFT
# MTF ~ CDI + PFT + DBH_mean                     False                 CDI, PFT
# MTF ~ CDI + DBH_mean                           False                      CDI
# MTF ~ DBH_mean                                  True
# MTF ~ MAT + Soil_water_max + PFT               False      MAT, Soil_water_max
# MTF ~ MAT + Soil_water + PFT                   False          MAT, Soil_water
# MTF ~ MATsoil + Soil_water_max + PFT           False  MATsoil, Soil_water_max
# MTF ~ CDI                                       True
# MTF ~ MATsoil                                  False                  MATsoil
# MTF ~ MATsoil + MAP                            False             MATsoil, MAP
# MTF ~ MATsoil + Soil_water                     False      MATsoil, Soil_water
# MTF ~ MAT                                      False                      MAT
# MTF ~ MAP                                      False                      MAP
# MTF ~ MAT + MAP                                False                 MAT, MAP
# MTF ~ MATsoil + Soil_water_max                 False  MATsoil, Soil_water_max
# MTF ~ MAT + Soil_water                         False          MAT, Soil_water
# MTF ~ Soil_water                               False               Soil_water
# MTF ~ MAT + Soil_water_max                     False      MAT, Soil_water_max
# MTF ~ Soil_water_max                           False           Soil_water_max
#
#                                              N_obs  ID MTF_basis    climate  \
# MTF ~ MAT + Humidity + PFT + DBH_mean        109.0   0     count  CRUNCEPv7
# MTF ~ MATsoil + Humidity + PFT + DBH_mean    109.0   1     count  CRUNCEPv7
# MTF ~ MAT + Soil_water_max + PFT + DBH_mean  109.0   2     count  CRUNCEPv7
# MTF ~ MAT + PFT + DBH_mean                   109.0   3     count  CRUNCEPv7
# MTF ~ MAT + Soil_water_max + DBH_mean        109.0   4     count  CRUNCEPv7
# MTF ~ MAT + MAP + PFT + DBH_mean             109.0   5     count  CRUNCEPv7
# MTF ~ MAT + Soil_water + PFT + DBH_mean      109.0   6     count  CRUNCEPv7
# MTF ~ MAT + DBH_mean                         109.0   7     count  CRUNCEPv7
# MTF ~ MAT + Soil_water + DBH_mean            109.0   8     count  CRUNCEPv7
# MTF ~ MAT + MAP + DBH_mean                   109.0   9     count  CRUNCEPv7
# MTF ~ Humidity + PFT + DBH_mean              109.0  10     count  CRUNCEPv7
# MTF ~ MATsoil + DBH_mean                     109.0  11     count  CRUNCEPv7
# MTF ~ MATsoil + PFT + DBH_mean               109.0  12     count  CRUNCEPv7
# MTF ~ Humidity + DBH_mean                    109.0  13     count  CRUNCEPv7
# MTF ~ PFT + DBH_mean                         109.0  14     count  CRUNCEPv7
# MTF ~ CDI + PFT + DBH_mean                   109.0  15     count  CRUNCEPv7
# MTF ~ CDI + DBH_mean                         109.0  16     count  CRUNCEPv7
# MTF ~ DBH_mean                               109.0  17     count  CRUNCEPv7
# MTF ~ MAT + Soil_water_max + PFT             109.0  18     count  CRUNCEPv7
# MTF ~ MAT + Soil_water + PFT                 109.0  19     count  CRUNCEPv7
# MTF ~ MATsoil + Soil_water_max + PFT         109.0  20     count  CRUNCEPv7
# MTF ~ CDI                                    109.0  21     count  CRUNCEPv7
# MTF ~ MATsoil                                109.0  22     count  CRUNCEPv7
# MTF ~ MATsoil + MAP                          109.0  23     count  CRUNCEPv7
# MTF ~ MATsoil + Soil_water                   109.0  24     count  CRUNCEPv7
# MTF ~ MAT                                    109.0  25     count  CRUNCEPv7
# MTF ~ MAP                                    109.0  26     count  CRUNCEPv7
# MTF ~ MAT + MAP                              109.0  27     count  CRUNCEPv7
# MTF ~ MATsoil + Soil_water_max               109.0  28     count  CRUNCEPv7
# MTF ~ MAT + Soil_water                       109.0  29     count  CRUNCEPv7
# MTF ~ Soil_water                             109.0  30     count  CRUNCEPv7
# MTF ~ MAT + Soil_water_max                   109.0  31     count  CRUNCEPv7
# MTF ~ Soil_water_max                         109.0  32     count  CRUNCEPv7
#
#                                              standardised_covars
# MTF ~ MAT + Humidity + PFT + DBH_mean                       True
# MTF ~ MATsoil + Humidity + PFT + DBH_mean                   True
# MTF ~ MAT + Soil_water_max + PFT + DBH_mean                 True
# MTF ~ MAT + PFT + DBH_mean                                  True
# MTF ~ MAT + Soil_water_max + DBH_mean                       True
# MTF ~ MAT + MAP + PFT + DBH_mean                            True
# MTF ~ MAT + Soil_water + PFT + DBH_mean                     True
# MTF ~ MAT + DBH_mean                                        True
# MTF ~ MAT + Soil_water + DBH_mean                           True
# MTF ~ MAT + MAP + DBH_mean                                  True
# MTF ~ Humidity + PFT + DBH_mean                             True
# MTF ~ MATsoil + DBH_mean                                    True
# MTF ~ MATsoil + PFT + DBH_mean                              True
# MTF ~ Humidity + DBH_mean                                   True
# MTF ~ PFT + DBH_mean                                        True
# MTF ~ CDI + PFT + DBH_mean                                  True
# MTF ~ CDI + DBH_mean                                        True
# MTF ~ DBH_mean                                              True
# MTF ~ MAT + Soil_water_max + PFT                            True
# MTF ~ MAT + Soil_water + PFT                                True
# MTF ~ MATsoil + Soil_water_max + PFT                        True
# MTF ~ CDI                                                   True
# MTF ~ MATsoil                                               True
# MTF ~ MATsoil + MAP                                         True
# MTF ~ MATsoil + Soil_water                                  True
# MTF ~ MAT                                                   True
# MTF ~ MAP                                                   True
# MTF ~ MAT + MAP                                             True
# MTF ~ MATsoil + Soil_water_max                              True
# MTF ~ MAT + Soil_water                                      True
# MTF ~ Soil_water                                            True
# MTF ~ MAT + Soil_water_max                                  True
# MTF ~ Soil_water_max                                        True
# ==============================
#
#              cmass
#
# ==============================
#
# CDI 0.3095014336017726
# DBH_mean 30.43507263788527
# Humidity 1.7656554432160267
# MAP 907.3834862385319
# MAT 5.720183486238534
# MATsoil 6.546789010730358
# PFT 0.7614678899082569
# Soil_water 0.5596014192891777
# Soil_water_max 0.6797675443898648
#                                          r2    AIC  d_AIC   RMSE   DWT  \
# MTF ~ MAT + Humidity + PFT + DBH_mean  0.58  227.5    0.0  44.39  1.16
# MTF ~ MAT + Humidity + DBH_mean        0.55  232.4    4.9  44.78  1.01
# MTF ~ MAT + MAP + PFT + DBH_mean       0.48  249.6   22.1  48.19  0.89
# MTF ~ Humidity + PFT + DBH_mean        0.47  250.8   23.3  45.97  1.03
# MTF ~ MAT + DBH_mean                   0.47  250.9   23.4  48.14  0.83
# MTF ~ MAT + Soil_water + DBH_mean      0.47  251.2   23.7  47.74  0.86
# MTF ~ MAT + MAP + DBH_mean             0.47  252.4   24.9  48.01  0.82
# MTF ~ Humidity + DBH_mean              0.44  255.6   28.1  45.74  0.88
# MTF ~ MATsoil + DBH_mean               0.42  259.9   32.4  50.72  0.73
# MTF ~ MATsoil + PFT + DBH_mean         0.42  260.4   32.9  50.91  0.75
# MTF ~ CDI + DBH_mean                   0.34  273.7   46.2  51.97  0.67
# MTF ~ DBH_mean                         0.34  274.2   46.7  51.23  0.69
# MTF ~ CDI                              0.04  313.9   86.4  66.22  0.75
# MTF ~ MATsoil                          0.01  317.5   90.0  66.65  0.68
# MTF ~ MAT                              0.01  317.8   90.3  66.65  0.70
# MTF ~ MATsoil + MAP                    0.01  318.7   91.2  66.52  0.71
# MTF ~ MAP                              0.00  318.3   90.8  66.38  0.74
# MTF ~ MAT + MAP                        0.00  319.2   91.7  66.50  0.72
# MTF ~ MATsoil + Soil_water_max         0.00  319.5   92.0  66.65  0.68
# MTF ~ MAT + Soil_water_max            -0.00  319.7   92.2  66.66  0.69
# MTF ~ Soil_water_max                  -0.01  319.7   92.2  66.52  0.73
#
#                                       prms_sig                prms_fail  \
# MTF ~ MAT + Humidity + PFT + DBH_mean     True
# MTF ~ MAT + Humidity + DBH_mean           True
# MTF ~ MAT + MAP + PFT + DBH_mean         False                      MAP
# MTF ~ Humidity + PFT + DBH_mean           True
# MTF ~ MAT + DBH_mean                      True
# MTF ~ MAT + Soil_water + DBH_mean        False               Soil_water
# MTF ~ MAT + MAP + DBH_mean               False                      MAP
# MTF ~ Humidity + DBH_mean                 True
# MTF ~ MATsoil + DBH_mean                  True
# MTF ~ MATsoil + PFT + DBH_mean           False                      PFT
# MTF ~ CDI + DBH_mean                     False                      CDI
# MTF ~ DBH_mean                            True
# MTF ~ CDI                                 True
# MTF ~ MATsoil                            False                  MATsoil
# MTF ~ MAT                                False                      MAT
# MTF ~ MATsoil + MAP                      False             MATsoil, MAP
# MTF ~ MAP                                False                      MAP
# MTF ~ MAT + MAP                          False                 MAT, MAP
# MTF ~ MATsoil + Soil_water_max           False  MATsoil, Soil_water_max
# MTF ~ MAT + Soil_water_max               False      MAT, Soil_water_max
# MTF ~ Soil_water_max                     False           Soil_water_max
#
#                                        N_obs  ID MTF_basis    climate  \
# MTF ~ MAT + Humidity + PFT + DBH_mean  109.0   0     cmass  CRUNCEPv7
# MTF ~ MAT + Humidity + DBH_mean        109.0   1     cmass  CRUNCEPv7
# MTF ~ MAT + MAP + PFT + DBH_mean       109.0   2     cmass  CRUNCEPv7
# MTF ~ Humidity + PFT + DBH_mean        109.0   3     cmass  CRUNCEPv7
# MTF ~ MAT + DBH_mean                   109.0   4     cmass  CRUNCEPv7
# MTF ~ MAT + Soil_water + DBH_mean      109.0   5     cmass  CRUNCEPv7
# MTF ~ MAT + MAP + DBH_mean             109.0   6     cmass  CRUNCEPv7
# MTF ~ Humidity + DBH_mean              109.0   7     cmass  CRUNCEPv7
# MTF ~ MATsoil + DBH_mean               109.0   8     cmass  CRUNCEPv7
# MTF ~ MATsoil + PFT + DBH_mean         109.0   9     cmass  CRUNCEPv7
# MTF ~ CDI + DBH_mean                   109.0  10     cmass  CRUNCEPv7
# MTF ~ DBH_mean                         109.0  11     cmass  CRUNCEPv7
# MTF ~ CDI                              109.0  12     cmass  CRUNCEPv7
# MTF ~ MATsoil                          109.0  13     cmass  CRUNCEPv7
# MTF ~ MAT                              109.0  14     cmass  CRUNCEPv7
# MTF ~ MATsoil + MAP                    109.0  15     cmass  CRUNCEPv7
# MTF ~ MAP                              109.0  16     cmass  CRUNCEPv7
# MTF ~ MAT + MAP                        109.0  17     cmass  CRUNCEPv7
# MTF ~ MATsoil + Soil_water_max         109.0  18     cmass  CRUNCEPv7
# MTF ~ MAT + Soil_water_max             109.0  19     cmass  CRUNCEPv7
# MTF ~ Soil_water_max                   109.0  20     cmass  CRUNCEPv7
#
#                                        standardised_covars
# MTF ~ MAT + Humidity + PFT + DBH_mean                 True
# MTF ~ MAT + Humidity + DBH_mean                       True
# MTF ~ MAT + MAP + PFT + DBH_mean                      True
# MTF ~ Humidity + PFT + DBH_mean                       True
# MTF ~ MAT + DBH_mean                                  True
# MTF ~ MAT + Soil_water + DBH_mean                     True
# MTF ~ MAT + MAP + DBH_mean                            True
# MTF ~ Humidity + DBH_mean                             True
# MTF ~ MATsoil + DBH_mean                              True
# MTF ~ MATsoil + PFT + DBH_mean                        True
# MTF ~ CDI + DBH_mean                                  True
# MTF ~ DBH_mean                                        True
# MTF ~ CDI                                             True
# MTF ~ MATsoil                                         True
# MTF ~ MAT                                             True
# MTF ~ MATsoil + MAP                                   True
# MTF ~ MAP                                             True
# MTF ~ MAT + MAP                                       True
# MTF ~ MATsoil + Soil_water_max                        True
# MTF ~ MAT + Soil_water_max                            True
# MTF ~ Soil_water_max                                  True
