# %%
# Load libraries
import pandas as pd
import pickle
import os

# %config Completer.use_jedi = False 

#--- Notebook run settings
run = 'command line' # 'manual' 'command line'
#run = 'manual'


# Settings for the multiple linear regression model (MLR)
#--- Arguments
if run == 'command line':
    # Read command line arguments
    arguments = os.environ['NB_ARGS']
    alpha, date_exp_str_full, date_exp_str_managed, remove_data = arguments.split(',')
    
    alpha              = float(alpha)
    remove_data        = bool(remove_data)
    
elif run == 'manual':
    # Enter arguments manually 
    alpha                = 0.01
    date_exp_str_managed = '230413_Management'
    remove_data          = True


with open('spe_reg_results/'+date_exp_str_managed+'_best_model_climate_'+str(remove_data)+'_'+str(alpha)+'_species.pkl','rb') as f:
    species_clim_best_models = pickle.load(f)
with open('site_reg_results/'+date_exp_str_managed+'_best_model_climate_'+str(remove_data)+'_'+str(alpha)+'_site.pkl','rb') as f:
    site_clim_best_models = pickle.load(f)    

# Finish table    
species_clim_best_models.index = ['Species']*6
species_clim_best_models.index.name = 'Level'
species_clim_best_models = species_clim_best_models.reset_index().set_index(['Level','model'])
site_clim_best_models.index = ['Site']*6
site_clim_best_models.index.name = 'Level'
site_clim_best_models = site_clim_best_models.reset_index().set_index(['Level','model'])

table_climate_comparison = pd.concat([site_clim_best_models,species_clim_best_models],axis=0)
display(table_climate_comparison)

print(table_climate_comparison.to_latex())
# Out:
#                                                  climate MTFcount         \
#                                                                r2    AIC
# Level   model
# Site    MTF ~ MAT + DBH_mean + Managed           CRUclim     0.34  149.2
#         MTF ~ MAT + DBH_mean + Managed         CRUNCEPv7     0.36  147.1
#         MTF ~ MAT + DBH_mean + Managed         CHELSA30s      0.3  152.8
#         MTF ~ MAT + DBH_mean + Managed      WorldClim30s     0.34    149
#         MTF ~ MAT + DBH_mean + Managed      WorldClim10m     0.32  150.8
#         MTF ~ MATsoil + DBH_mean + Managed     SoilTemps     0.34  148.7
# Species MTF ~ MAT + DBH_mean + Managed           CRUclim     0.61  200.1
#         MTF ~ MAT + DBH_mean + Managed         CRUNCEPv7     0.61  198.8
#         MTF ~ MAT + DBH_mean + Managed         CHELSA30s     0.58  207.9
#         MTF ~ MAT + DBH_mean + Managed      WorldClim30s     0.58  207.2
#         MTF ~ MAT + DBH_mean + Managed      WorldClim10m     0.55  214.3
#         MTF ~ MATsoil + DBH_mean + Managed     SoilTemps     0.62  196.5
#
#                                                   MTFcmass
#                                              RMSE       r2    AIC   RMSE
# Level   model
# Site    MTF ~ MAT + DBH_mean + Managed      23.67      0.4  152.9  49.59
#         MTF ~ MAT + DBH_mean + Managed      23.44     0.42  150.8  49.25
#         MTF ~ MAT + DBH_mean + Managed      24.63     0.35  157.5  51.15
#         MTF ~ MAT + DBH_mean + Managed      24.47      0.4  152.2  51.21
#         MTF ~ MAT + DBH_mean + Managed      24.46     0.39  153.9  50.89
#         MTF ~ MATsoil + DBH_mean + Managed  24.44      0.4  152.1   51.1
# Species MTF ~ MAT + DBH_mean + Managed      25.94      0.6    221   43.9
#         MTF ~ MAT + DBH_mean + Managed      26.01      0.6  220.4  44.08
#         MTF ~ MAT + DBH_mean + Managed      26.29     0.57  228.7  43.31
#         MTF ~ MAT + DBH_mean + Managed      27.32     0.56  230.6  46.44
#         MTF ~ MAT + DBH_mean + Managed      27.35     0.54  234.2  45.38
#         MTF ~ MATsoil + DBH_mean + Managed  26.84     0.59  221.2  45.95
# \begin{tabular}{lllllllll}
# \toprule
#         &                                    &       climate & \multicolumn{3}{l}{MTFcount} & \multicolumn{3}{l}{MTFcmass} \\
#         &                                    &       r2 &    AIC &   RMSE &       r2 &    AIC &   RMSE \\
# Level & model &               &          &        &        &          &        &        \\
# \midrule
# Site & MTF \textasciitilde  MAT + DBH\_mean + Managed &       CRUclim &     0.34 &  149.2 &  23.67 &      0.4 &  152.9 &  49.59 \\
#         & MTF \textasciitilde  MAT + DBH\_mean + Managed &     CRUNCEPv7 &     0.36 &  147.1 &  23.44 &     0.42 &  150.8 &  49.25 \\
#         & MTF \textasciitilde  MAT + DBH\_mean + Managed &     CHELSA30s &      0.3 &  152.8 &  24.63 &     0.35 &  157.5 &  51.15 \\
#         & MTF \textasciitilde  MAT + DBH\_mean + Managed &  WorldClim30s &     0.34 &    149 &  24.47 &      0.4 &  152.2 &  51.21 \\
#         & MTF \textasciitilde  MAT + DBH\_mean + Managed &  WorldClim10m &     0.32 &  150.8 &  24.46 &     0.39 &  153.9 &  50.89 \\
#         & MTF \textasciitilde  MATsoil + DBH\_mean + Managed &     SoilTemps &     0.34 &  148.7 &  24.44 &      0.4 &  152.1 &   51.1 \\
# Species & MTF \textasciitilde  MAT + DBH\_mean + Managed &       CRUclim &     0.61 &  200.1 &  25.94 &      0.6 &    221 &   43.9 \\
#         & MTF \textasciitilde  MAT + DBH\_mean + Managed &     CRUNCEPv7 &     0.61 &  198.8 &  26.01 &      0.6 &  220.4 &  44.08 \\
#         & MTF \textasciitilde  MAT + DBH\_mean + Managed &     CHELSA30s &     0.58 &  207.9 &  26.29 &     0.57 &  228.7 &  43.31 \\
#         & MTF \textasciitilde  MAT + DBH\_mean + Managed &  WorldClim30s &     0.58 &  207.2 &  27.32 &     0.56 &  230.6 &  46.44 \\
#         & MTF \textasciitilde  MAT + DBH\_mean + Managed &  WorldClim10m &     0.55 &  214.3 &  27.35 &     0.54 &  234.2 &  45.38 \\
#         & MTF \textasciitilde  MATsoil + DBH\_mean + Managed &     SoilTemps &     0.62 &  196.5 &  26.84 &     0.59 &  221.2 &  45.95 \\
# \bottomrule
# \end{tabular}
